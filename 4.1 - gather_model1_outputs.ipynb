# %%
import torch
import torchvision
import os
import pickle
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision.transforms import v2
import matplotlib.pyplot as plt
import torch.nn as nn
from PIL import Image
from torchcam.methods import SmoothGradCAMpp
from utils import imread, isfile, im_to_txt_path, imwrite
from timer import *
from torchvision.transforms import transforms as T
import cv2
from dataset_operations import clip_value

parent_dir = 'rois2/'
obj_dir = parent_dir + 'objects/'
img_dir = parent_dir + 'images/'
label_dir = parent_dir + 'labels/'
model_dir = parent_dir + 'models/'

result_dir = parent_dir + 'results/'
os.makedirs(result_dir, exist_ok=True)
model1_result_dir = result_dir + 'model1/'
os.makedirs(model1_result_dir, exist_ok=True)

os.makedirs(model1_result_dir + 'train', exist_ok=True)
os.makedirs(model1_result_dir + 'val', exist_ok=True)

obj_train_dir = obj_dir + 'train/'
obj_val_dir = obj_dir + 'val/'

os.makedirs(obj_train_dir, exist_ok=True)
os.makedirs(obj_val_dir, exist_ok=True)

# %%
def gather_detections(roi_fp, model, save_dir = model1_result_dir, window_size=512, stride=256, 
                      score_thr=0.5, nms_thr=0.5, intersect_thr=0.5,
                      box_width_thr = [20,500], box_area_thr = [200,150000], box_ratio_thr = 0.2, clean_up = True):
    
    if clean_up:
        for dirpath, dirnames, filenames in os.walk(model1_result_dir + 'train'):
            for filename in [f for f in filenames if f.endswith(".txt")]:
                os.remove(os.path.join(dirpath, filename))
                
        for dirpath, dirnames, filenames in os.walk(model1_result_dir + 'test'):
            for filename in [f for f in filenames if f.endswith(".txt")]:
                os.remove(os.path.join(dirpath, filename))
    
    
    model.eval()
    roi_name = roi_fp.split('/')[-1].split('.')[0]
    # print(roi_name)
    result_file_path = save_dir + roi_name + '.txt'
    result_file = open(result_file_path, 'w')
    
    orig_roi = imread(roi_fp)
    roi_w = orig_roi.shape[1]
    roi_h = orig_roi.shape[0]
    roi = cv2.copyMakeBorder(orig_roi, 0, window_size - roi_h % window_size, 0, window_size - roi_w % window_size, cv2.BORDER_CONSTANT, value=[0, 0, 0])
    if roi is None:
        print('     Error: No roi file found')
        return 0
    
    
    # load and record groundtruth labels
    true_boxes = []
    if isfile(im_to_txt_path(roi_fp)):
        with open(im_to_txt_path(roi_fp), 'r') as f:
            for line in f:
                temp_label = [int(x) for x in line.strip().split(' ')]
                true_boxes.append([temp_label[1], temp_label[2], temp_label[3], temp_label[4]])
    obj_map = torch.zeros((roi_h, roi_w))
    for box in true_boxes:
        obj_map[box[1]:box[3], box[0]:box[2]] = (box[3] - box[1]) * (box[2] - box[0])
    
    
    print('     roi width: ', roi_w, ' roi height: ', roi_h)
    # slide the window from top left to bottom right
    start_x = 0
    while start_x <= roi_w:
        windows = []
        offsets = []
        
        start_y = 0
        while start_y <= roi_h: 
            end_x = int(start_x + window_size)
            end_y = int(start_y + window_size)
            window = roi[start_y:end_y, start_x:end_x]
            window = torch.tensor(window).permute(2,0,1).float().to('cuda')
            # print(window.shape)
            windows.append(window)
            offsets.append([start_x, start_y])
            
            start_y += stride
        # print('     number of windows: ', len(windows))
        
        
        preds = model(windows)
        for idx, pred in enumerate(preds):
            # window_timer.start()
            
            offset = offsets[idx]
            filtered_idx = torchvision.ops.nms(pred['boxes'], pred['scores'], nms_thr)
            # print("     Time to perform NMS on current window: ", nms_timer.elapsed_time())
            
            pred_boxes = pred['boxes'][filtered_idx]
            pred_scores = pred['scores'][filtered_idx]
            
            for score, box in zip(pred_scores,pred_boxes):
                # score thr
                if score < score_thr:
                    continue
                
                pred_box_x1 = int(box[0] + offset[0])
                pred_box_y1 = int(box[1] + offset[1])
                pred_box_x2 = int(box[2] + offset[0])
                pred_box_y2 = int(box[3] + offset[1])
                
                #  size thr
                if (pred_box_x2 - pred_box_x1) * (pred_box_y2 - pred_box_y1) < box_area_thr[0] \
                    or (pred_box_x2 - pred_box_x1) * (pred_box_y2 - pred_box_y1) > box_area_thr[1] \
                    or pred_box_x2 - pred_box_x1 < box_width_thr[0] or pred_box_x2 - pred_box_x1 > box_width_thr[1] \
                    or pred_box_y2 - pred_box_y1 < box_width_thr[0] or pred_box_y2 - pred_box_y1 > box_width_thr[1] \
                    or (pred_box_x2 - pred_box_x1) * (pred_box_y2 - pred_box_y1) < box_area_thr[0] \
                    or (pred_box_x2 - pred_box_x1) / (pred_box_y2 - pred_box_y1) < box_ratio_thr \
                    or (pred_box_y2 - pred_box_y1) / (pred_box_x2 - pred_box_x1) < box_ratio_thr:
                    continue
                
                pred_obj_type = 0
                # iou thr
                intersect_area = (obj_map[pred_box_y1:pred_box_y2, pred_box_x1:pred_box_x2] > 0).sum().item()
                pred_area = (pred_box_x2 - pred_box_x1) * (pred_box_y2 - pred_box_y1)
                
                if intersect_area > 0:
                    obj_area = torch.max(obj_map[pred_box_y1:pred_box_y2, pred_box_x1:pred_box_x2]).item()
                    if pred_area >= (pred_area + obj_area - intersect_area) * intersect_thr:
                        pred_obj_type = 1
                    
                result_file.write(f"{pred_box_x1} {pred_box_y1} {pred_box_x2} {pred_box_y2} {pred_obj_type}\n")
        start_x += stride

# %%
detect_model = torchvision.models.detection.ssdlite320_mobilenet_v3_large(num_classes=2).to('cuda')
detect_model.load_state_dict(torch.load('rois2/models/round2_2/round2_model_epoch6.pth'))
# Out:
# <All keys matched successfully>

# %%
train_roi_paths = []
f = open(img_dir + 'train_rois.txt', 'r')
lines = f.readlines()
for line in lines:
    train_roi_paths.append(line.strip())
f.close()

timer = Timer()
for i, roi_path in enumerate(train_roi_paths):
    file_name = model1_result_dir + 'train/' +  roi_path.split('/')[-1].split('.')[0] + '.txt'
    
    if isfile(file_name) and os.path.getsize(file_name) > 0:
        print('ROI [', i+1, '/', len(train_roi_paths),'] Already tested, skipping...')
        continue
    
    
    print('ROI [', i+1, '/', len(train_roi_paths),'] Processing ', roi_path)
    
    timer.start()
    gather_detections(roi_path, detect_model, save_dir = model1_result_dir + 'train/', 
                      nms_thr=0.1, score_thr=0.5, intersec_thr = 1)
    timer.stop()
    print('     Time to process ', roi_path, ': ', timer.elapsed_time())
# Out:
# ROI [ 1 / 334 ] Processing  rois2/images/expert1_id-6381471f7f8a5e686a52765f_left-36214_top-41262_right-39265_bottom-46232.png
#      roi width:  3051  roi height:  4970
#      Time to process  rois2/images/expert1_id-6381471f7f8a5e686a52765f_left-36214_top-41262_right-39265_bottom-46232.png :  0 hours, 0 minutes, 11.55 seconds
# ROI [ 2 / 334 ] Processing  rois2/images/expert1_id-6381471f7f8a5e686a52765f_left-36627_top-47431_right-39464_bottom-52356.png
#      roi width:  2837  roi height:  4925
#      Time to process  rois2/images/expert1_id-6381471f7f8a5e686a52765f_left-36627_top-47431_right-39464_bottom-52356.png :  0 hours, 0 minutes, 11.56 seconds
# ROI [ 3 / 334 ] Processing  rois2/images/expert1_id-6381471f7f8a5e686a527706_left-75035_top-24698_right-80405_bottom-28610.png
#      roi width:  5370  roi height:  3912
#      Time to process  rois2/images/expert1_id-6381471f7f8a5e686a527706_left-75035_top-24698_right-80405_bottom-28610.png :  0 hours, 0 minutes, 17.39 seconds
# ROI [ 4 / 334 ] Processing  rois2/images/expert1_id-6381471f7f8a5e686a5277c2_left-68060_top-39334_right-73669_bottom-44184.png
#      roi width:  5609  roi height:  4850
#      Time to process  rois2/images/expert1_id-6381471f7f8a5e686a5277c2_left-68060_top-39334_right-73669_bottom-44184.png :  0 hours, 0 minutes, 20.85 seconds
# ROI [ 5 / 334 ] Processing  rois2/images/expert1_id-6381471f7f8a5e686a52781f_left-70416_top-29678_right-75686_bottom-33272.png
#      roi width:  5270  roi height:  3594
#      Time to process  rois2/images/expert1_id-6381471f7f8a5e686a52781f_left-70416_top-29678_right-75686_bottom-33272.png :  0 hours, 0 minutes, 15.07 seconds
# ROI [ 6 / 334 ] Processing  rois2/images/expert1_id-638147207f8a5e686a527923_left-84307_top-28200_right-89535_bottom-31674.png
#      roi width:  5228  roi height:  3474
#      Time to process  rois2/images/expert1_id-638147207f8a5e686a527923_left-84307_top-28200_right-89535_bottom-31674.png :  0 hours, 0 minutes, 15.56 seconds
# ROI [ 7 / 334 ] Processing  rois2/images/expert1_id-638147207f8a5e686a527a86_left-81390_top-42976_right-86847_bottom-48436.png
#      roi width:  5457  roi height:  5460
#      Time to process  rois2/images/expert1_id-638147207f8a5e686a527a86_left-81390_top-42976_right-86847_bottom-48436.png :  0 hours, 0 minutes, 26.66 seconds
# ROI [ 8 / 334 ] Processing  rois2/images/expert1_id-638147207f8a5e686a527b36_left-31319_top-23629_right-35766_bottom-29239.png
#      roi width:  4447  roi height:  5610
#      Time to process  rois2/images/expert1_id-638147207f8a5e686a527b36_left-31319_top-23629_right-35766_bottom-29239.png :  0 hours, 0 minutes, 21.33 seconds
# ROI [ 9 / 334 ] Processing  rois2/images/expert1_id-638147217f8a5e686a527c6c_left-50697_top-18712_right-56296_bottom-23938.png
#      roi width:  5599  roi height:  5226
#      Time to process  rois2/images/expert1_id-638147217f8a5e686a527c6c_left-50697_top-18712_right-56296_bottom-23938.png :  0 hours, 0 minutes, 27.15 seconds
# ROI [ 10 / 334 ] Processing  rois2/images/expert1_id-638147217f8a5e686a527cb2_left-62803_top-57114_right-67115_bottom-62698.png
#      roi width:  4312  roi height:  5584
#      Time to process  rois2/images/expert1_id-638147217f8a5e686a527cb2_left-62803_top-57114_right-67115_bottom-62698.png :  0 hours, 0 minutes, 21.04 seconds
# ROI [ 11 / 334 ] Processing  rois2/images/expert1_id-638147227f8a5e686a527d03_left-39360_top-4098_right-44240_bottom-6918.png
#      roi width:  4880  roi height:  2820
#      Time to process  rois2/images/expert1_id-638147227f8a5e686a527d03_left-39360_top-4098_right-44240_bottom-6918.png :  0 hours, 0 minutes, 14.16 seconds
# ROI [ 12 / 334 ] Processing  rois2/images/expert1_id-638147227f8a5e686a527e9f_left-94451_top-69988_right-99928_bottom-75217.png
#      roi width:  5477  roi height:  5229
#      Time to process  rois2/images/expert1_id-638147227f8a5e686a527e9f_left-94451_top-69988_right-99928_bottom-75217.png :  0 hours, 0 minutes, 23.94 seconds
# ROI [ 13 / 334 ] Processing  rois2/images/expert1_id-638147237f8a5e686a527eb1_left-42999_top-55467_right-46519_bottom-60706.png
#      roi width:  3520  roi height:  5239
#      Time to process  rois2/images/expert1_id-638147237f8a5e686a527eb1_left-42999_top-55467_right-46519_bottom-60706.png :  0 hours, 0 minutes, 16.45 seconds
# ROI [ 14 / 334 ] Processing  rois2/images/expert1_id-638147237f8a5e686a527edf_left-39635_top-31927_right-43166_bottom-37182.png
#      roi width:  3531  roi height:  5255
#      Time to process  rois2/images/expert1_id-638147237f8a5e686a527edf_left-39635_top-31927_right-43166_bottom-37182.png :  0 hours, 0 minutes, 19.17 seconds
# ROI [ 15 / 334 ] Processing  rois2/images/expert1_id-638147237f8a5e686a527f5b_left-10248_top-46842_right-15844_bottom-52058.png
#      roi width:  5596  roi height:  5216
#      Time to process  rois2/images/expert1_id-638147237f8a5e686a527f5b_left-10248_top-46842_right-15844_bottom-52058.png :  0 hours, 0 minutes, 26.43 seconds
# ROI [ 16 / 334 ] Processing  rois2/images/expert1_id-638147237f8a5e686a528046_left-94174_top-47564_right-98376_bottom-53010.png
#      roi width:  4202  roi height:  5446
#      Time to process  rois2/images/expert1_id-638147237f8a5e686a528046_left-94174_top-47564_right-98376_bottom-53010.png :  0 hours, 0 minutes, 20.76 seconds
# ROI [ 17 / 334 ] Processing  rois2/images/expert1_id-638147247f8a5e686a528082_left-47811_top-11372_right-53047_bottom-16868.png
#      roi width:  5236  roi height:  5496
#      Time to process  rois2/images/expert1_id-638147247f8a5e686a528082_left-47811_top-11372_right-53047_bottom-16868.png :  0 hours, 0 minutes, 25.89 seconds
# ROI [ 18 / 334 ] Processing  rois2/images/expert1_id-638147247f8a5e686a5280f3_left-89438_top-46522_right-94897_bottom-50573.png
#      roi width:  5459  roi height:  4051
#      Time to process  rois2/images/expert1_id-638147247f8a5e686a5280f3_left-89438_top-46522_right-94897_bottom-50573.png :  0 hours, 0 minutes, 19.00 seconds
# ROI [ 19 / 334 ] Processing  rois2/images/expert1_id-638147247f8a5e686a528139_left-71845_top-35583_right-77415_bottom-40281.png
#      roi width:  5570  roi height:  4698
#      Time to process  rois2/images/expert1_id-638147247f8a5e686a528139_left-71845_top-35583_right-77415_bottom-40281.png :  0 hours, 0 minutes, 23.17 seconds
# ROI [ 20 / 334 ] Processing  rois2/images/expert1_id-638147257f8a5e686a528301_left-68935_top-27767_right-74578_bottom-32500.png
#      roi width:  5643  roi height:  4733
#      Time to process  rois2/images/expert1_id-638147257f8a5e686a528301_left-68935_top-27767_right-74578_bottom-32500.png :  0 hours, 0 minutes, 24.33 seconds
# ROI [ 21 / 334 ] Processing  rois2/images/expert1_id-638147257f8a5e686a528386_left-29553_top-13354_right-35192_bottom-18356.png
#      roi width:  5639  roi height:  5002
#      Time to process  rois2/images/expert1_id-638147257f8a5e686a528386_left-29553_top-13354_right-35192_bottom-18356.png :  0 hours, 0 minutes, 27.12 seconds
# ROI [ 22 / 334 ] Processing  rois2/images/expert1_id-638147257f8a5e686a5283de_left-54771_top-54457_right-59862_bottom-57788.png
#      roi width:  5091  roi height:  3331
#      Time to process  rois2/images/expert1_id-638147257f8a5e686a5283de_left-54771_top-54457_right-59862_bottom-57788.png :  0 hours, 0 minutes, 17.38 seconds
# ROI [ 23 / 334 ] Processing  rois2/images/expert1_id-638147267f8a5e686a5284dd_left-81104_top-31426_right-86095_bottom-34490.png
#      roi width:  4991  roi height:  3064
#      Time to process  rois2/images/expert1_id-638147267f8a5e686a5284dd_left-81104_top-31426_right-86095_bottom-34490.png :  0 hours, 0 minutes, 14.70 seconds
# ROI [ 24 / 334 ] Processing  rois2/images/expert1_id-638147267f8a5e686a528518_left-28058_top-35469_right-33697_bottom-40218.png
#      roi width:  5639  roi height:  4749
#      Time to process  rois2/images/expert1_id-638147267f8a5e686a528518_left-28058_top-35469_right-33697_bottom-40218.png :  0 hours, 0 minutes, 24.48 seconds
# ROI [ 25 / 334 ] Processing  rois2/images/expert1_id-638147267f8a5e686a528518_left-52047_top-38417_right-57612_bottom-43189.png
#      roi width:  5565  roi height:  4772
#      Time to process  rois2/images/expert1_id-638147267f8a5e686a528518_left-52047_top-38417_right-57612_bottom-43189.png :  0 hours, 0 minutes, 24.88 seconds
# ROI [ 26 / 334 ] Processing  rois2/images/expert1_id-638147267f8a5e686a528518_left-57467_top-41862_right-63012_bottom-46265.png
#      roi width:  5545  roi height:  4403
#      Time to process  rois2/images/expert1_id-638147267f8a5e686a528518_left-57467_top-41862_right-63012_bottom-46265.png :  0 hours, 0 minutes, 23.36 seconds
# ROI [ 27 / 334 ] Processing  rois2/images/expert1_id-638147267f8a5e686a528518_left-66806_top-19952_right-72239_bottom-23890.png
#      roi width:  5433  roi height:  3938
#      Time to process  rois2/images/expert1_id-638147267f8a5e686a528518_left-66806_top-19952_right-72239_bottom-23890.png :  0 hours, 0 minutes, 20.59 seconds
# ROI [ 28 / 334 ] Processing  rois2/images/expert1_id-638147267f8a5e686a5286ad_left-75804_top-10842_right-80632_bottom-13702.png
#      roi width:  4828  roi height:  2860
#      Time to process  rois2/images/expert1_id-638147267f8a5e686a5286ad_left-75804_top-10842_right-80632_bottom-13702.png :  0 hours, 0 minutes, 14.60 seconds
# ROI [ 47 / 334 ] Processing  rois2/images/expert2_id-638147427f8a5e686a52aaed_left-32161_top-57712_right-37515_bottom-63199.png
#      roi width:  5354  roi height:  5487
#      Time to process  rois2/images/expert2_id-638147427f8a5e686a52aaed_left-32161_top-57712_right-37515_bottom-63199.png :  0 hours, 0 minutes, 27.39 seconds
# ROI [ 48 / 334 ] Processing  rois2/images/expert2_id-638147427f8a5e686a52ab08_left-50579_top-6525_right-55696_bottom-10042.png
#      roi width:  5117  roi height:  3517
#      Time to process  rois2/images/expert2_id-638147427f8a5e686a52ab08_left-50579_top-6525_right-55696_bottom-10042.png :  0 hours, 0 minutes, 15.84 seconds
# ROI [ 49 / 334 ] Processing  rois2/images/expert2_id-638147427f8a5e686a52ab1c_left-50602_top-71521_right-56259_bottom-76521.png
#      roi width:  5657  roi height:  5000
#      Time to process  rois2/images/expert2_id-638147427f8a5e686a52ab1c_left-50602_top-71521_right-56259_bottom-76521.png :  0 hours, 0 minutes, 24.30 seconds
# ROI [ 50 / 334 ] Processing  rois2/images/expert2_id-638147437f8a5e686a52ab79_left-68935_top-27767_right-74578_bottom-32500.png
#      roi width:  5643  roi height:  4733
#      Time to process  rois2/images/expert2_id-638147437f8a5e686a52ab79_left-68935_top-27767_right-74578_bottom-32500.png :  0 hours, 0 minutes, 23.38 seconds
# ROI [ 51 / 334 ] Processing  rois2/images/expert2_id-638147437f8a5e686a52abc1_left-46045_top-47985_right-50299_bottom-53498.png
#      roi width:  4254  roi height:  5513
#      Time to process  rois2/images/expert2_id-638147437f8a5e686a52abc1_left-46045_top-47985_right-50299_bottom-53498.png :  0 hours, 0 minutes, 21.82 seconds
# ROI [ 52 / 334 ] Processing  rois2/images/expert2_id-638147437f8a5e686a52ac6f_left-56042_top-35368_right-60866_bottom-38216.png
#      roi width:  4824  roi height:  2848
#      Time to process  rois2/images/expert2_id-638147437f8a5e686a52ac6f_left-56042_top-35368_right-60866_bottom-38216.png :  0 hours, 0 minutes, 14.22 seconds
# ROI [ 53 / 334 ] Processing  rois2/images/expert2_id-638147447f8a5e686a52acc8_left-46986_top-30036_right-51832_bottom-35643.png
#      roi width:  4846  roi height:  5607
#      Time to process  rois2/images/expert2_id-638147447f8a5e686a52acc8_left-46986_top-30036_right-51832_bottom-35643.png :  0 hours, 0 minutes, 24.38 seconds
# ROI [ 54 / 334 ] Processing  rois2/images/expert2_id-638147447f8a5e686a52ad23_left-60086_top-25975_right-65358_bottom-29678.png
#      roi width:  5272  roi height:  3703
#      Time to process  rois2/images/expert2_id-638147447f8a5e686a52ad23_left-60086_top-25975_right-65358_bottom-29678.png :  0 hours, 0 minutes, 19.72 seconds
# ROI [ 55 / 334 ] Processing  rois2/images/expert2_id-638147447f8a5e686a52ad45_left-42068_top-26041_right-47232_bottom-31588.png
#      roi width:  5164  roi height:  5547
#      Time to process  rois2/images/expert2_id-638147447f8a5e686a52ad45_left-42068_top-26041_right-47232_bottom-31588.png :  0 hours, 0 minutes, 17.22 seconds
left-39635_top-31927_right-43166_bottom-37182.png
#      roi width:  3531  roi height:  5255
#      Time to process  rois2/images/expert3_id-638147177f8a5e686a5268b9_left-39635_top-31927_right-43166_bottom-37182.png :  0 hours, 0 minutes, 18.16 seconds
# ROI [ 76 / 334 ] Processing  rois2/images/expert3_id-638147187f8a5e686a526958_left-32524_top-47100_right-37847_bottom-50820.png
#      roi width:  5323  roi height:  3720
#      Time to process  rois2/images/expert3_id-638147187f8a5e686a526958_left-32524_top-47100_right-37847_bottom-50820.png :  0 hours, 0 minutes, 17.01 seconds
# ROI [ 77 / 334 ] Processing  rois2/images/expert3_id-638147187f8a5e686a52699d_left-90225_top-42334_right-95472_bottom-45932.png
#      roi width:  5247  roi height:  3598
#      Time to process  rois2/images/expert3_id-638147187f8a5e686a52699d_left-90225_top-42334_right-95472_bottom-45932.png :  0 hours, 0 minutes, 17.69 seconds
# ROI [ 78 / 334 ] Processing  rois2/images/expert3_id-638147187f8a5e686a5269d4_left-47811_top-11372_right-53047_bottom-16868.png
#      roi width:  5236  roi height:  5496
#      Time to process  rois2/images/expert3_id-638147187f8a5e686a5269d4_left-47811_top-11372_right-53047_bottom-16868.png :  0 hours, 0 minutes, 24.56 seconds
# ROI [ 79 / 334 ] Processing  rois2/images/expert3_id-638147187f8a5e686a5269d4_left-71022_top-11200_right-76574_bottom-15749.png
#      roi width:  5552  roi height:  4549
#      Time to process  rois2/images/expert3_id-638147187f8a5e686a5269d4_left-71022_top-11200_right-76574_bottom-15749.png :  0 hours, 0 minutes, 21.02 seconds
# ROI [ 80 / 334 ] Processing  rois2/images/expert3_id-638147187f8a5e686a526a51_left-71845_top-35583_right-77415_bottom-40281.png
#      roi width:  5570  roi height:  4698
#      Time to process  rois2/images/expert3_id-638147187f8a5e686a526a51_left-71845_top-35583_right-77415_bottom-40281.png :  0 hours, 0 minutes, 22.08 seconds
# ROI [ 81 / 334 ] Processing  rois2/images/expert3_id-638147197f8a5e686a526b0a_left-28062_top-23625_right-33141_bottom-29234.png
#      roi width:  5079  roi height:  5609
#      Time to process  rois2/images/expert3_id-638147197f8a5e686a526b0a_left-28062_top-23625_right-33141_bottom-29234.png :  0 hours, 0 minutes, 24.89 seconds
# ROI [ 82 / 334 ] Processing  rois2/images/expert3_id-638147197f8a5e686a526b96_left-61079_top-40736_right-64798_bottom-46091.png
#      roi width:  3719  roi height:  5355
#      Time to process  rois2/images/expert3_id-638147197f8a5e686a526b96_left-61079_top-40736_right-64798_bottom-46091.png :  0 hours, 0 minutes, 15.96 seconds
# ROI [ 83 / 334 ] Processing  rois2/images/expert3_id-638147197f8a5e686a526b96_left-68935_top-27767_right-74578_bottom-32500.png
#      roi width:  5643  roi height:  4733
#      roi width:  5218  roi height:  5607
#      Time to process  rois2/images/expert4_id-638147607f8a5e686a52d99f_left-30020_top-44454_right-35238_bottom-50061.png :  0 hours, 0 minutes, 27.56 seconds
# ROI [ 129 / 334 ] Processing  rois2/images/expert4_id-638147607f8a5e686a52da68_left-43902_top-29891_right-49515_bottom-34615.png
#      roi width:  5613  roi height:  4724
#      Time to process  rois2/images/expert4_id-638147607f8a5e686a52da68_left-43902_top-29891_right-49515_bottom-34615.png :  0 hours, 0 minutes, 24.21 seconds
# ROI [ 130 / 334 ] Processing  rois2/images/expert4_id-638147617f8a5e686a52dad4_left-53084_top-51554_right-58553_bottom-56892.png
#      roi width:  5469  roi height:  5338
#      Time to process  rois2/images/expert4_id-638147617f8a5e686a52dad4_left-53084_top-51554_right-58553_bottom-56892.png :  0 hours, 0 minutes, 28.51 seconds
# ROI [ 131 / 334 ] Processing  rois2/images/expert4_id-638147617f8a5e686a52dbc3_left-47297_top-69897_right-50342_bottom-74822.png
#      roi width:  3045  roi height:  4925
#      Time to process  rois2/images/expert4_id-638147617f8a5e686a52dbc3_left-47297_top-69897_right-50342_bottom-74822.png :  0 hours, 0 minutes, 15.21 seconds
# ROI [ 132 / 334 ] Processing  rois2/images/expert4_id-638147617f8a5e686a52dc5b_left-25422_top-14885_right-30942_bottom-20277.png
#      roi width:  5520  roi height:  5392
#      Time to process  rois2/images/expert4_id-638147617f8a5e686a52dc5b_left-25422_top-14885_right-30942_bottom-20277.png :  0 hours, 0 minutes, 25.30 seconds
# ROI [ 133 / 334 ] Processing  rois2/images/expert4_id-638147627f8a5e686a52dcd0_left-68708_top-52685_right-74381_bottom-57571.png
#      roi width:  5673  roi height:  4886
#      Time to process  rois2/images/expert4_id-638147627f8a5e686a52dcd0_left-68708_top-52685_right-74381_bottom-57571.png :  0 hours, 0 minutes, 23.75 seconds
# ROI [ 134 / 334 ] Processing  rois2/images/expert4_id-638147627f8a5e686a52dda8_left-23385_top-15229_right-28966_bottom-19976.png
#      roi width:  5581  roi height:  4747
#      Time to process  rois2/images/expert4_id-638147627f8a5e686a52dda8_left-23385_top-15229_right-28966_bottom-19976.png :  0 hours, 0 minutes, 22.26 seconds
# ROI [ 135 / 334 ] Processing  rois2/images/expert5_id-6381472c7f8a5e686a528abe_left-21014_top-20676_right-26347_bottom-24417.png
#      roi width:  5333  roi height:  3741
#      Time to process  rois2/images/expert5_id-6381472c7f8a5e686a528abe_left-21014_top-20676_right-26347_bottom-24417.png :  0 hours, 0 minutes, 15.28 seconds
# ROI [ 136 / 334 ] Processing  rois2/images/expert5_id-6381472c7f8a5e686a528adf_left-73441_top-38789_right-79090_bottom-43383.png
#      roi width:  5649  roi height:  4594
#      Time to process  rois2/images/expert5_id-6381472c7f8a5e686a528adf_left-73441_top-38789_right-79090_bottom-43383.png :  0 hours, 0 minutes, 18.60 seconds
# ROI [ 137 / 334 ] Processing  rois2/images/expert5_id-6381472c7f8a5e686a528b26_left-21596_top-19693_right-27011_bottom-25242.png
#      roi width:  5415  roi height:  5549
left-39635_top-31927_right-43166_bottom-37182.png
#      roi width:  3531  roi height:  5255
# ...
# ROI [ 285 / 334 ] Processing  rois2/images/novice3_id-640b6f43a7dbca00a13b1c33_left-47811_top-11372_right-53047_bottom-16868.png
#      roi width:  5236  roi height:  5496
#      Time to process  rois2/images/novice3_id-640b6f43a7dbca00a13b1c33_left-47811_top-11372_right-53047_bottom-16868.png :  0 hours, 0 minutes, 22.58 seconds
# ROI [ 286 / 334 ] Processing  rois2/images/novice3_id-640b6f43a7dbca00a13b1c78_left-71845_top-35583_right-77415_bottom-40281.png
#      roi width:  5570  roi height:  4698
#      Time to process  rois2/images/novice3_id-640b6f43a7dbca00a13b1c78_left-71845_top-35583_right-77415_bottom-40281.png :  0 hours, 0 minutes, 22.60 seconds
# ROI [ 287 / 334 ] Processing  rois2/images/novice3_id-640b6f43a7dbca00a13b1d79_left-68935_top-27767_right-74578_bottom-32500.png
#      roi width:  5643  roi height:  4733
#      Time to process  rois2/images/novice3_id-640b6f43a7dbca00a13b1d79_left-68935_top-27767_right-74578_bottom-32500.png :  0 hours, 0 minutes, 23.26 seconds
# ROI [ 288 / 334 ] Processing  rois2/images/novice3_id-640b6f44a7dbca00a13b1fb8_left-46986_top-30036_right-51832_bottom-35643.png
#      roi width:  4846  roi height:  5607
#      Time to process  rois2/images/novice3_id-640b6f44a7dbca00a13b1fb8_left-46986_top-30036_right-51832_bottom-35643.png :  0 hours, 0 minutes, 22.42 seconds
# ROI [ 289 / 334 ] Processing  rois2/images/novice3_id-640b6f44a7dbca00a13b2168_left-43737_top-31758_right-48225_bottom-37402.png
#      roi width:  4488  roi height:  5644
#      Time to process  rois2/images/novice3_id-640b6f44a7dbca00a13b2168_left-43737_top-31758_right-48225_bottom-37402.png :  0 hours, 0 minutes, 16.51 seconds
# ROI [ 290 / 334 ] Processing  rois2/images/novice4_id-640b6f40a7dbca00a13b168a_left-36627_top-47431_right-39464_bottom-52356.png
#      roi width:  2837  roi height:  4925
#      Time to process  rois2/images/novice4_id-640b6f40a7dbca00a13b168a_left-36627_top-47431_right-39464_bottom-52356.png :  0 hours, 0 minutes, 11.71 seconds
# ROI [ 291 / 334 ] Processing  rois2/images/novice4_id-640b6f40a7dbca00a13b16b5_left-73441_top-38789_right-79090_bottom-43383.png
#      roi width:  5649  roi height:  4594
#      Time to process  rois2/images/novice4_id-640b6f40a7dbca00a13b16b5_left-73441_top-38789_right-79090_bottom-43383.png :  0 hours, 0 minutes, 20.25 seconds
# ROI [ 292 / 334 ] Processing  rois2/images/novice4_id-640b6f40a7dbca00a13b17dc_left-81390_top-42976_right-86847_bottom-48436.png
#      roi width:  5457  roi height:  5460
#      Time to process  rois2/images/novice4_id-640b6f40a7dbca00a13b17dc_left-81390_top-42976_right-86847_bottom-48436.png :  0 hours, 0 minutes, 24.30 seconds
# ROI [ 293 / 334 ] Processing  rois2/images/novice4_id-640b6f41a7dbca00a13b18db_left-74157_top-47276_right-79805_bottom-51913.png
#      roi width:  5648  roi height:  4637
#      Time to process  rois2/images/novice4_id-640b6f41a7dbca00a13b18db_left-74157_top-47276_right-79805_bottom-51913.png :  0 hours, 0 minutes, 21.24 seconds
# ROI [ 294 / 334 ] Processing  rois2/images/novice4_id-640b6f41a7dbca00a13b199e_left-39360_top-4098_right-44240_bottom-6918.png
#      roi width:  4880  roi height:  2820
#      Time to process  rois2/images/novice4_id-640b6f41a7dbca00a13b199e_left-39360_top-4098_right-44240_bottom-6918.png :  0 hours, 0 minutes, 14.92 seconds
# ROI [ 295 / 334 ] Processing  rois2/images/novice4_id-640b6f42a7dbca00a13b19e0_left-110163_top-32695_right-114084_bottom-38122.png
#      roi width:  3921  roi height:  5427
#      Time to process  rois2/images/novice4_id-640b6f42a7dbca00a13b19e0_left-110163_top-32695_right-114084_bottom-38122.png :  0 hours, 0 minutes, 18.92 seconds
# ROI [ 296 / 334 ] Processing  rois2/images/novice4_id-640b6f42a7dbca00a13b1a78_left-39635_top-31927_right-43166_bottom-37182.png
#      roi width:  3531  roi height:  5255
#      Time to process  rois2/images/novice4_id-640b6f42a7dbca00a13b1a78_left-39635_top-31927_right-43166_bottom-37182.png :  0 hours, 0 minutes, 17.24 seconds
# ROI [ 297 / 334 ] Processing  rois2/images/novice4_id-640b6f43a7dbca00a13b1b14_left-32524_top-47100_right-37847_bottom-50820.png
#      roi width:  5323  roi height:  3720
#      Time to process  rois2/images/novice4_id-640b6f43a7dbca00a13b1b14_left-32524_top-47100_right-37847_bottom-50820.png :  0 hours, 0 minutes, 17.70 seconds
# ROI [ 298 / 334 ] Processing  rois2/images/novice4_id-640b6f43a7dbca00a13b1c33_left-47811_top-11372_right-53047_bottom-16868.png
#      roi width:  5236  roi height:  5496
#      Time to process  rois2/images/novice4_id-640b6f43a7dbca00a13b1c33_left-47811_top-11372_right-53047_bottom-16868.png :  0 hours, 0 minutes, 23.14 seconds
# ROI [ 299 / 334 ] Processing  rois2/images/novice4_id-640b6f43a7dbca00a13b1c78_left-71845_top-35583_right-77415_bottom-40281.png
#      roi width:  5570  roi height:  4698
#      Time to process  rois2/images/novice4_id-640b6f43a7dbca00a13b1c78_left-71845_top-35583_right-77415_bottom-40281.png :  0 hours, 0 minutes, 22.91 seconds
# ROI [ 300 / 334 ] Processing  rois2/images/novice4_id-640b6f44a7dbca00a13b1e01_left-46045_top-47985_right-50299_bottom-53498.png
#      roi width:  4254  roi height:  5513
#      Time to process  rois2/images/novice4_id-640b6f44a7dbca00a13b1e01_left-46045_top-47985_right-50299_bottom-53498.png :  0 hours, 0 minutes, 22.74 seconds
# ROI [ 301 / 334 ] Processing  rois2/images/novice4_id-640b6f44a7dbca00a13b1eae_left-73968_top-40902_right-77814_bottom-46263.png
#      roi width:  3846  roi height:  5361
#      Time to process  rois2/images/novice4_id-640b6f44a7dbca00a13b1eae_left-73968_top-40902_right-77814_bottom-46263.png :  0 hours, 0 minutes, 19.22 seconds
#      roi width:  6106  roi height:  5237
#      Time to process  rois2/images/_id-638149657f8a5e686a68181d_left-93738_top-57644_right-99844_bottom-62881.png :  0 hours, 0 minutes, 30.48 seconds
# ROI [ 321 / 334 ] Processing  rois2/images/_id-638149657f8a5e686a681825_left-113422_top-23357_right-119451_bottom-28951.png
#      roi width:  6029  roi height:  5594
#      Time to process  rois2/images/_id-638149657f8a5e686a681825_left-113422_top-23357_right-119451_bottom-28951.png :  0 hours, 0 minutes, 29.88 seconds
# ROI [ 322 / 334 ] Processing  rois2/images/_id-638149657f8a5e686a681829_left-39246_top-34101_right-44582_bottom-37045.png
#      roi width:  5336  roi height:  2944
#      Time to process  rois2/images/_id-638149657f8a5e686a681829_left-39246_top-34101_right-44582_bottom-37045.png :  0 hours, 0 minutes, 17.11 seconds
# ROI [ 323 / 334 ] Processing  rois2/images/_id-638149657f8a5e686a68187c_left-49760_top-26770_right-54958_bottom-29688.png
#      roi width:  5198  roi height:  2918
#      Time to process  rois2/images/_id-638149657f8a5e686a68187c_left-49760_top-26770_right-54958_bottom-29688.png :  0 hours, 0 minutes, 16.27 seconds
# ROI [ 324 / 334 ] Processing  rois2/images/_id-638149657f8a5e686a681888_left-50218_top-57247_right-55526_bottom-60167.png
#      roi width:  5308  roi height:  2920
#      Time to process  rois2/images/_id-638149657f8a5e686a681888_left-50218_top-57247_right-55526_bottom-60167.png :  0 hours, 0 minutes, 17.25 seconds
# ROI [ 325 / 334 ] Processing  rois2/images/_id-638149667f8a5e686a681894_left-36623_top-31430_right-41823_bottom-34266.png
#      roi width:  5200  roi height:  2836
#      Time to process  rois2/images/_id-638149667f8a5e686a681894_left-36623_top-31430_right-41823_bottom-34266.png :  0 hours, 0 minutes, 15.30 seconds
# ROI [ 326 / 334 ] Processing  rois2/images/_id-638149667f8a5e686a6818a2_left-64569_top-40401_right-69797_bottom-43291.png
#      roi width:  5228  roi height:  2890
#      Time to process  rois2/images/_id-638149667f8a5e686a6818a2_left-64569_top-40401_right-69797_bottom-43291.png :  0 hours, 0 minutes, 16.51 seconds
# ROI [ 327 / 334 ] Processing  rois2/images/_id-638149667f8a5e686a6818c4_left-40007_top-36686_right-45339_bottom-39622.png
#      roi width:  5332  roi height:  2936
#      Time to process  rois2/images/_id-638149667f8a5e686a6818c4_left-40007_top-36686_right-45339_bottom-39622.png :  0 hours, 0 minutes, 16.66 seconds
# ROI [ 328 / 334 ] Processing  rois2/images/_id-6381496b7f8a5e686a682ac9_left-37534_top-58392_right-43338_bottom-64196.png
#      roi width:  5804  roi height:  5804
#      Time to process  rois2/images/_id-6381496b7f8a5e686a682ac9_left-37534_top-58392_right-43338_bottom-64196.png :  0 hours, 0 minutes, 27.31 seconds
# ROI [ 329 / 334 ] Processing  rois2/images/_id-6381496b7f8a5e686a682acf_left-52243_top-58382_right-57563_bottom-61332.png
#      roi width:  5320  roi height:  2950
#      Time to process  rois2/images/_id-6381496b7f8a5e686a682acf_left-52243_top-58382_right-57563_bottom-61332.png :  0 hours, 0 minutes, 15.18 seconds
# ROI [ 330 / 334 ] Processing  rois2/images/_id-6381496b7f8a5e686a682ad1_left-89982_top-33440_right-95296_bottom-36382.png
#      roi width:  5314  roi height:  2942
#      Time to process  rois2/images/_id-6381496b7f8a5e686a682ad1_left-89982_top-33440_right-95296_bottom-36382.png :  0 hours, 0 minutes, 15.74 seconds
# ROI [ 331 / 334 ] Processing  rois2/images/_id-6381496b7f8a5e686a682ad3_left-76310_top-48713_right-81562_bottom-51617.png
#      roi width:  5252  roi height:  2904
#      Time to process  rois2/images/_id-6381496b7f8a5e686a682ad3_left-76310_top-48713_right-81562_bottom-51617.png :  0 hours, 0 minutes, 14.66 seconds
# ROI [ 332 / 334 ] Processing  rois2/images/_id-6381496b7f8a5e686a682ad9_left-60737_top-27077_right-66073_bottom-30027.png
#      roi width:  5336  roi height:  2950
#      Time to process  rois2/images/_id-6381496b7f8a5e686a682ad9_left-60737_top-27077_right-66073_bottom-30027.png :  0 hours, 0 minutes, 15.99 seconds
# ROI [ 333 / 334 ] Processing  rois2/images/_id-6381496b7f8a5e686a682adf_left-72972_top-22288_right-78214_bottom-25176.png
#      roi width:  5242  roi height:  2888
#      Time to process  rois2/images/_id-6381496b7f8a5e686a682adf_left-72972_top-22288_right-78214_bottom-25176.png :  0 hours, 0 minutes, 15.23 seconds
# ROI [ 334 / 334 ] Processing  rois2/images/_id-6381496b7f8a5e686a682ae7_left-101819_top-61337_right-107163_bottom-64285.png
#      roi width:  5344  roi height:  2948
#      Time to process  rois2/images/_id-6381496b7f8a5e686a682ae7_left-101819_top-61337_right-107163_bottom-64285.png :  0 hours, 0 minutes, 15.28 seconds

# %%
test_roi_paths = []
f = open(img_dir + 'test_rois.txt', 'r')
lines = f.readlines()
for line in lines:
    test_roi_paths.append(line.strip())
f.close()

timer = Timer()
for i, roi_path in enumerate(test_roi_paths):
    file_name = model1_result_dir + 'test' + roi_path.split('/')[-1].split('.')[0] + '.txt'
    
    if isfile(file_name) and os.path.getsize(file_name) > 0:
        print('ROI [', i+1, '/', len(test_roi_paths),'] Already tested, skipping...')
        continue
    
    
    print('ROI [', i+1, '/', len(test_roi_paths),'] Processing ', roi_path)
    
    timer.start()
    gather_detections(roi_path, detect_model, save_dir = model1_result_dir + 'test/', 
                      nms_thr=0.5, score_thr=0.1)
    timer.stop()
    print('     Time to process: ', timer.elapsed_time())
# Out:
# ROI [ 1 / 71 ] Processing  rois2/images/expert4_id-6381475a7f8a5e686a52cd62_left-62410_top-42230_right-67996_bottom-47544.png
#      roi width:  5586  roi height:  5314
#      Time to process:  0 hours, 0 minutes, 23.38 seconds
# ROI [ 2 / 71 ] Processing  rois2/images/expert3_id-638147157f8a5e686a5266b6_left-89851_top-19583_right-95249_bottom-23467.png
#      roi width:  5398  roi height:  3884
#      Time to process:  0 hours, 0 minutes, 18.62 seconds
# ROI [ 3 / 71 ] Processing  rois2/images/novice4_id-640b6f43a7dbca00a13b1d79_left-68935_top-27767_right-74578_bottom-32500.png
#      roi width:  5643  roi height:  4733
#      Time to process:  0 hours, 0 minutes, 23.28 seconds
# ROI [ 4 / 71 ] Processing  rois2/images/expert3_id-638147197f8a5e686a526b96_left-64449_top-32580_right-69312_bottom-38239.png
#      roi width:  4863  roi height:  5659
#      Time to process:  0 hours, 0 minutes, 22.84 seconds
# ROI [ 5 / 71 ] Processing  rois2/images/expert2_id-638147437f8a5e686a52abc1_left-46904_top-41335_right-50634_bottom-46685.png
#      roi width:  3730  roi height:  5350
#      Time to process:  0 hours, 0 minutes, 18.60 seconds
# ROI [ 6 / 71 ] Processing  rois2/images/expert4_id-6381475e7f8a5e686a52d5b0_left-68935_top-27767_right-74578_bottom-32500.png
#      roi width:  5643  roi height:  4733
#      Time to process:  0 hours, 0 minutes, 24.07 seconds
# ROI [ 7 / 71 ] Processing  rois2/images/expert3_id-638147157f8a5e686a5266df_left-81390_top-42976_right-86847_bottom-48436.png
#      roi width:  5457  roi height:  5460
#      Time to process:  0 hours, 0 minutes, 24.80 seconds
# ROI [ 8 / 71 ] Processing  rois2/images/novice3_id-638147387f8a5e686a52998b_left-39635_top-31927_right-43166_bottom-37182.png
#      roi width:  3531  roi height:  5255
#      Time to process:  0 hours, 0 minutes, 17.86 seconds
# ROI [ 9 / 71 ] Processing  rois2/images/novice2_id-638147557f8a5e686a52c650_left-42585_top-21938_right-48190_bottom-26544.png
#      roi width:  5605  roi height:  4606
#      Time to process:  0 hours, 0 minutes, 22.92 seconds
# ROI [ 10 / 71 ] Processing  rois2/images/expert5_id-638147317f8a5e686a5290bc_left-41675_top-55774_right-44961_bottom-60778.png
#      roi width:  3286  roi height:  5004
#      Time to process:  0 hours, 0 minutes, 15.11 seconds
# ROI [ 11 / 71 ] Processing  rois2/images/expert1_id-638147227f8a5e686a527db5_left-110163_top-32695_right-114084_bottom-38122.png
#      roi width:  3921  roi height:  5427
#      Time to process:  0 hours, 0 minutes, 17.77 seconds
# ROI [ 12 / 71 ] Processing  rois2/images/novice2_id-638147567f8a5e686a52c725_left-66669_top-42792_right-71632_bottom-48416.png
#      roi width:  4963  roi height:  5624
#      Time to process:  0 hours, 0 minutes, 26.17 seconds
# ROI [ 13 / 71 ] Processing  rois2/images/novice3_id-6381473c7f8a5e686a52a3e4_left-65116_top-23422_right-68824_bottom-28677.png
#      roi width:  3708  roi height:  5255
#      Time to process:  0 hours, 0 minutes, 16.29 seconds
# ROI [ 14 / 71 ] Processing  rois2/images/_id-6381496b7f8a5e686a682ad5_left-50351_top-45730_right-55659_bottom-48696.png
#      roi width:  5308  roi height:  2966
#      Time to process:  0 hours, 0 minutes, 15.01 seconds
# ROI [ 15 / 71 ] Processing  rois2/images/novice2_id-638147547f8a5e686a52c2f7_left-37172_top-40615_right-41589_bottom-46211.png
#      roi width:  4417  roi height:  5596
#      Time to process:  0 hours, 0 minutes, 20.48 seconds
# ROI [ 16 / 71 ] Processing  rois2/images/expert3_id-638147157f8a5e686a526692_left-95857_top-57504_right-100593_bottom-63137.png
#      roi width:  4736  roi height:  5633
#      Time to process:  0 hours, 0 minutes, 21.57 seconds
# ROI [ 17 / 71 ] Processing  rois2/images/_id-638149277f8a5e686a6564d7_left-14506_top-42878_right-20158_bottom-47699.png
#      roi width:  5652  roi height:  4821
#      Time to process:  0 hours, 0 minutes, 26.76 seconds
# ROI [ 18 / 71 ] Processing  rois2/images/novice2_id-638147507f8a5e686a52bee4_left-58000_top-54422_right-62957_bottom-60045.png
#      roi width:  4957  roi height:  5623
#      Time to process:  0 hours, 0 minutes, 20.78 seconds
# ROI [ 19 / 71 ] Processing  rois2/images/expert2_id-6381473d7f8a5e686a52a563_left-36627_top-47431_right-39464_bottom-52356.png
#      roi width:  2837  roi height:  4925
#      Time to process:  0 hours, 0 minutes, 10.61 seconds
# ROI [ 20 / 71 ] Processing  rois2/images/_id-638149657f8a5e686a681823_left-25909_top-17876_right-29818_bottom-23497.png
#      roi width:  3909  roi height:  5621
#      Time to process:  0 hours, 0 minutes, 17.50 seconds
# ROI [ 21 / 71 ] Processing  rois2/images/expert3_id-6381471e7f8a5e686a52750c_left-46125_top-22398_right-50997_bottom-28061.png
#      roi width:  4872  roi height:  5663
#      Time to process:  0 hours, 0 minutes, 22.24 seconds
# ROI [ 22 / 71 ] Processing  rois2/images/_id-638149277f8a5e686a656488_left-47054_top-17926_right-50925_bottom-23421.png
#      roi width:  3871  roi height:  5495
#      Time to process:  0 hours, 0 minutes, 17.44 seconds
# ROI [ 23 / 71 ] Processing  rois2/images/novice3_id-638147387f8a5e686a52998b_left-30886_top-24999_right-36299_bottom-28931.png
#      roi width:  5413  roi height:  3932
#      Time to process:  0 hours, 0 minutes, 20.31 seconds
# ROI [ 24 / 71 ] Processing  rois2/images/expert5_id-638147327f8a5e686a5292ac_left-54051_top-31323_right-58616_bottom-36929.png
#      roi width:  4565  roi height:  5606
#      Time to process:  0 hours, 0 minutes, 18.85 seconds
# ROI [ 25 / 71 ] Processing  rois2/images/novice3_id-638147397f8a5e686a529ce4_left-83802_top-26156_right-89077_bottom-29840.png
#      roi width:  5275  roi height:  3684
#      Time to process:  0 hours, 0 minutes, 18.46 seconds
# ROI [ 26 / 71 ] Processing  rois2/images/novice3_id-640b6f44a7dbca00a13b1eae_left-73968_top-40902_right-77814_bottom-46263.png
#      roi width:  3846  roi height:  5361
#      Time to process:  0 hours, 0 minutes, 19.70 seconds
# ROI [ 27 / 71 ] Processing  rois2/images/novice1_id-6381474f7f8a5e686a52bcd3_left-43545_top-63203_right-49040_bottom-67419.png
#      roi width:  5495  roi height:  4216
#      Time to process:  0 hours, 0 minutes, 20.14 seconds
# ROI [ 28 / 71 ] Processing  rois2/images/_id-6381487a7f8a5e686a5e00d3_left-87953_top-42229_right-93237_bottom-45540.png
#      roi width:  5284  roi height:  3311
#      Time to process:  0 hours, 0 minutes, 18.52 seconds
# ROI [ 29 / 71 ] Processing  rois2/images/expert1_id-638147237f8a5e686a527feb_left-32524_top-47100_right-37847_bottom-50820.png
#      roi width:  5323  roi height:  3720
#      Time to process:  0 hours, 0 minutes, 17.13 seconds
# ROI [ 30 / 71 ] Processing  rois2/images/expert4_id-6381475a7f8a5e686a52ce6f_left-65867_top-35034_right-69745_bottom-40396.png
#      roi width:  3878  roi height:  5362
#      Time to process:  0 hours, 0 minutes, 17.04 seconds
# ROI [ 31 / 71 ] Processing  rois2/images/novice2_id-638147597f8a5e686a52cc0f_left-84574_top-45354_right-90197_bottom-50262.png
#      roi width:  5623  roi height:  4908
#      Time to process:  0 hours, 0 minutes, 24.92 seconds
# ROI [ 32 / 71 ] Processing  rois2/images/expert3_id-6381471c7f8a5e686a5272d3_left-14031_top-37896_right-19695_bottom-42647.png
#      roi width:  5664  roi height:  4751
#      Time to process:  0 hours, 0 minutes, 23.85 seconds
# ROI [ 33 / 71 ] Processing  rois2/images/expert3_id-638147147f8a5e686a5265a3_left-36627_top-47431_right-39464_bottom-52356.png
#      roi width:  2837  roi height:  4925
#      Time to process:  0 hours, 0 minutes, 11.65 seconds
# ROI [ 34 / 71 ] Processing  rois2/images/_id-638149667f8a5e686a681896_left-44696_top-48846_right-50024_bottom-51710.png
#      roi width:  5328  roi height:  2864
#      Time to process:  0 hours, 0 minutes, 16.45 seconds
# ROI [ 35 / 71 ] Processing  rois2/images/expert3_id-638147187f8a5e686a526a1f_left-102551_top-45917_right-107403_bottom-48773.png
#      roi width:  4852  roi height:  2856
#      Time to process:  0 hours, 0 minutes, 13.09 seconds
# ROI [ 36 / 71 ] Processing  rois2/images/expert4_id-6381475b7f8a5e686a52ced9_left-81519_top-59401_right-86751_bottom-62907.png
#      roi width:  5232  roi height:  3506
#      Time to process:  0 hours, 0 minutes, 16.19 seconds
# ROI [ 37 / 71 ] Processing  rois2/images/expert5_id-6381472f7f8a5e686a528e65_left-23387_top-33885_right-28979_bottom-38720.png
#      roi width:  5592  roi height:  4835
#      Time to process:  0 hours, 0 minutes, 22.01 seconds
# ROI [ 38 / 71 ] Processing  rois2/images/expert5_id-6381472c7f8a5e686a528b5a_left-55472_top-35484_right-61116_bottom-40227.png
#      roi width:  5644  roi height:  4743
#      Time to process:  0 hours, 0 minutes, 22.02 seconds
# ROI [ 39 / 71 ] Processing  rois2/images/expert4_id-6381475c7f8a5e686a52d23c_left-47845_top-70248_right-52119_bottom-75771.png
#      roi width:  4274  roi height:  5523
#      Time to process:  0 hours, 0 minutes, 21.89 seconds
# ROI [ 40 / 71 ] Processing  rois2/images/expert3_id-638147177f8a5e686a5268b9_left-15253_top-58207_right-20780_bottom-63599.png
#      roi width:  5527  roi height:  5392
#      Time to process:  0 hours, 0 minutes, 26.70 seconds
# ROI [ 41 / 71 ] Processing  rois2/images/expert5_id-638147347f8a5e686a52940f_left-51097_top-8214_right-56069_bottom-11191.png
#      roi width:  4972  roi height:  2977
#      Time to process:  0 hours, 0 minutes, 17.34 seconds
# ROI [ 42 / 71 ] Processing  rois2/images/expert2_id-6381473f7f8a5e686a52a6a6_left-74157_top-47276_right-79805_bottom-51913.png
#      roi width:  5648  roi height:  4637
#      Time to process:  0 hours, 0 minutes, 21.35 seconds
# ROI [ 43 / 71 ] Processing  rois2/images/expert5_id-638147337f8a5e686a529361_left-79042_top-57208_right-83898_bottom-60036.png
#      roi width:  4856  roi height:  2828
#      Time to process:  0 hours, 0 minutes, 12.90 seconds
# ROI [ 44 / 71 ] Processing  rois2/images/expert4_id-638147607f8a5e686a52da68_left-44289_top-36635_right-49422_bottom-39950.png
#      roi width:  5133  roi height:  3315
#      Time to process:  0 hours, 0 minutes, 17.02 seconds
# ROI [ 45 / 71 ] Processing  rois2/images/expert4_id-6381475d7f8a5e686a52d2fe_left-98330_top-66914_right-103866_bottom-71938.png
#      roi width:  5536  roi height:  5024
#      Time to process:  0 hours, 0 minutes, 21.97 seconds
# ROI [ 46 / 71 ] Processing  rois2/images/novice3_id-6381473b7f8a5e686a52a04d_left-57637_top-70266_right-63268_bottom-75379.png
#      roi width:  5631  roi height:  5113
#      Time to process:  0 hours, 0 minutes, 26.86 seconds
# ROI [ 47 / 71 ] Processing  rois2/images/expert4_id-638147607f8a5e686a52d8e3_left-43737_top-31758_right-48225_bottom-37402.png
#      roi width:  4488  roi height:  5644
#      Time to process:  0 hours, 0 minutes, 16.50 seconds
# ROI [ 48 / 71 ] Processing  rois2/images/novice3_id-638147367f8a5e686a529693_left-85908_top-39914_right-91504_bottom-45252.png
#      roi width:  5596  roi height:  5338
#      Time to process:  0 hours, 0 minutes, 23.89 seconds
# ROI [ 49 / 71 ] Processing  rois2/images/expert4_id-6381475f7f8a5e686a52d745_left-46986_top-30036_right-51832_bottom-35643.png
#      roi width:  4846  roi height:  5607
#      Time to process:  0 hours, 0 minutes, 23.44 seconds
# ROI [ 50 / 71 ] Processing  rois2/images/expert5_id-638147307f8a5e686a528f49_left-57393_top-42771_right-61450_bottom-48230.png
#      roi width:  4057  roi height:  5459
#      Time to process:  0 hours, 0 minutes, 20.47 seconds
# ROI [ 51 / 71 ] Processing  rois2/images/novice2_id-638147587f8a5e686a52cb38_left-52228_top-46199_right-56445_bottom-51685.png
#      roi width:  4217  roi height:  5486
#      Time to process:  0 hours, 0 minutes, 20.50 seconds
# ROI [ 52 / 71 ] Processing  rois2/images/expert2_id-638147437f8a5e686a52abc1_left-50592_top-35898_right-56137_bottom-41171.png
#      roi width:  5545  roi height:  5273
#      Time to process:  0 hours, 0 minutes, 27.73 seconds
# ROI [ 53 / 71 ] Processing  rois2/images/expert2_id-638147447f8a5e686a52acc0_left-46379_top-45941_right-51211_bottom-48801.png
#      roi width:  4832  roi height:  2860
#      Time to process:  0 hours, 0 minutes, 15.00 seconds
# ROI [ 54 / 71 ] Processing  rois2/images/expert4_id-6381475d7f8a5e686a52d33d_left-38274_top-26234_right-43569_bottom-31793.png
#      roi width:  5295  roi height:  5559
#      Time to process:  0 hours, 0 minutes, 28.13 seconds
# ROI [ 55 / 71 ] Processing  rois2/images/expert3_id-6381471c7f8a5e686a527348_left-28496_top-24540_right-34189_bottom-29692.png
#      roi width:  5693  roi height:  5152
#      Time to process:  0 hours, 0 minutes, 24.41 seconds
# ROI [ 56 / 71 ] Processing  rois2/images/expert3_id-638147197f8a5e686a526b0a_left-60648_top-65928_right-66093_bottom-70024.png
#      roi width:  5445  roi height:  4096
#      Time to process:  0 hours, 0 minutes, 19.23 seconds
# ROI [ 57 / 71 ] Processing  rois2/images/novice3_id-638147347f8a5e686a5294c3_left-88241_top-43916_right-93149_bottom-46784.png
#      roi width:  4908  roi height:  2868
#      Time to process:  0 hours, 0 minutes, 14.02 seconds
# ROI [ 58 / 71 ] Processing  rois2/images/novice1_id-6381474d7f8a5e686a52b8fb_left-60365_top-24417_right-64075_bottom-29742.png
#      roi width:  3710  roi height:  5325
#      Time to process:  0 hours, 0 minutes, 17.35 seconds
# ROI [ 59 / 71 ] Processing  rois2/images/_id-638148a17f8a5e686a5fafed_left-53605_top-20867_right-58670_bottom-26354.png
#      roi width:  5065  roi height:  5487
#      Time to process:  0 hours, 0 minutes, 25.98 seconds
# ROI [ 60 / 71 ] Processing  rois2/images/novice1_id-6381474a7f8a5e686a52b42f_left-39635_top-31927_right-43166_bottom-37182.png
#      roi width:  3531  roi height:  5255
#      Time to process:  0 hours, 0 minutes, 17.37 seconds
# ROI [ 61 / 71 ] Processing  rois2/images/_id-638148f47f8a5e686a632df1_left-39144_top-42331_right-43041_bottom-47835.png
#      roi width:  3897  roi height:  5504
#      Time to process:  0 hours, 0 minutes, 21.65 seconds
# ROI [ 62 / 71 ] Processing  rois2/images/novice2_id-638147527f8a5e686a52c0bf_left-74157_top-47276_right-79805_bottom-51913.png
#      roi width:  5648  roi height:  4637
#      Time to process:  0 hours, 0 minutes, 21.22 seconds
# ROI [ 63 / 71 ] Processing  rois2/images/expert4_id-638147617f8a5e686a52dad4_left-53116_top-36604_right-58632_bottom-41995.png
#      roi width:  5516  roi height:  5391
#      Time to process:  0 hours, 0 minutes, 28.91 seconds
# ROI [ 64 / 71 ] Processing  rois2/images/expert2_id-638147467f8a5e686a52afdb_left-33856_top-22040_right-39007_bottom-25451.png
#      roi width:  5151  roi height:  3411
#      Time to process:  0 hours, 0 minutes, 17.79 seconds
# ROI [ 65 / 71 ] Processing  rois2/images/novice2_id-638147577f8a5e686a52c917_left-49450_top-22861_right-54314_bottom-25729.png
#      roi width:  4864  roi height:  2868
#      Time to process:  0 hours, 0 minutes, 15.67 seconds
# ROI [ 66 / 71 ] Processing  rois2/images/expert1_id-638147227f8a5e686a527db5_left-106926_top-15547_right-110362_bottom-20702.png
#      roi width:  3436  roi height:  5155
#      Time to process:  0 hours, 0 minutes, 14.95 seconds
# ROI [ 67 / 71 ] Processing  rois2/images/novice3_id-6381473a7f8a5e686a529e2e_left-71913_top-53877_right-77120_bottom-57371.png
#      roi width:  5207  roi height:  3494
#      Time to process:  0 hours, 0 minutes, 17.92 seconds
# ROI [ 68 / 71 ] Processing  rois2/images/expert2_id-638147417f8a5e686a52a8f5_left-39635_top-31927_right-43166_bottom-37182.png
#      roi width:  3531  roi height:  5255
#      Time to process:  0 hours, 0 minutes, 17.81 seconds
# ROI [ 69 / 71 ] Processing  rois2/images/expert1_id-6381471f7f8a5e686a52781f_left-55955_top-30871_right-61037_bottom-36488.png
#      roi width:  5082  roi height:  5617
#      Time to process:  0 hours, 0 minutes, 22.47 seconds
# ROI [ 70 / 71 ] Processing  rois2/images/expert1_id-638147257f8a5e686a528265_left-76247_top-34836_right-81874_bottom-39944.png
#      roi width:  5627  roi height:  5108
#      Time to process:  0 hours, 0 minutes, 24.06 seconds
# ROI [ 71 / 71 ] Processing  rois2/images/novice3_id-640b6f40a7dbca00a13b17dc_left-81390_top-42976_right-86847_bottom-48436.png
#      roi width:  5457  roi height:  5460
#      Time to process:  0 hours, 0 minutes, 24.38 seconds

# %%
# clean up the directory
for dir, subdirs, files in os.walk(obj_train_dir):
    for file in files:
        os.remove(os.path.join(dir, file))

for dir, subdirs, files in os.walk(obj_val_dir):
    for file in files:
        os.remove(os.path.join(dir, file))            

if os.path.exists(obj_train_dir):       
    for dir in os.listdir(obj_train_dir):
        os.removedirs(obj_train_dir + dir)
        
if os.path.exists(obj_val_dir):
    for dir in os.listdir(obj_val_dir):
        os.removedirs(obj_val_dir + dir)

# %%
def crop_detected_objects(read_dir, save_dir):    
    for dirpath, dirnames, filenames in os.walk(read_dir):
        for i, filename in enumerate(filenames):
            roi_path = img_dir + filename.split('.')[0] + '.png'
            roi_img = imread(roi_path).copy()
            w,h = roi_img.shape[1], roi_img.shape[0]
            # print(w,h)
            with open(os.path.join(dirpath, filename), 'r') as f:
                lines = f.readlines()
                for line in lines:
                    _, x1,y1,x2,y2,obj_type = line.strip().split(' ')
                    x1,y1,x2,y2,obj_type = int(x1), int(y1), int(x2), int(y2), str(obj_type)
                    x1,y1,x2,y2 = clip_value(x1, 0, w), clip_value(y1, 0, h), clip_value(x2, 0, w), clip_value(y2, 0, h)
                    
                    if x1 >= x2 or y1 >= y2:
                        continue
                    
                    if x2 - x1 < 20 or y2 - y1 < 20 or (x2 - x1) * (y2 - y1) < 200 or (x2 - x1) * (y2 - y1) > 150000:
                        continue
                    
                    temp_img = roi_img[y1:y2, x1:x2]
                    os.makedirs(save_dir + obj_type + '/', exist_ok=True)
                    imwrite(save_dir + obj_type + '/' + filename.split('.')[0] + '__' + str(x1) + '_' + str(y1) + '_' + str(x2) + '_' + str(y2) + '.png', temp_img)
            
            print('ROI processed [{}/{}]'.format(i + 1, len(filenames)) )

# %%
crop_detected_objects(model1_result_dir + 'train/', obj_train_dir)
# Out:
# ROI processed [1/334]
# ROI processed [2/334]
# ROI processed [3/334]
# ROI processed [4/334]
# ROI processed [5/334]
# ROI processed [6/334]
# ROI processed [7/334]
# ROI processed [8/334]
# ROI processed [9/334]
# ROI processed [10/334]
# ROI processed [11/334]
# ROI processed [12/334]
# ROI processed [13/334]
# ROI processed [14/334]
# ROI processed [15/334]
# ROI processed [16/334]
# ROI processed [17/334]
# ROI processed [18/334]
# ROI processed [19/334]
# ROI processed [20/334]
# ROI processed [21/334]
# ROI processed [22/334]
# ROI processed [23/334]
# ROI processed [24/334]
# ROI processed [25/334]
# ROI processed [26/334]
# ROI processed [27/334]
# ROI processed [28/334]
# ROI processed [29/334]
# ROI processed [30/334]
# ROI processed [31/334]
# ROI processed [32/334]
# ROI processed [33/334]
# ROI processed [34/334]
# ROI processed [35/334]
# ROI processed [36/334]
# ROI processed [37/334]
# ROI processed [38/334]
# ROI processed [39/334]
# ROI processed [40/334]
# ROI processed [41/334]
# ROI processed [42/334]
# ROI processed [43/334]
# ROI processed [44/334]
# ROI processed [45/334]
# ROI processed [46/334]
# ROI processed [47/334]
# ROI processed [48/334]
# ROI processed [49/334]
# ROI processed [50/334]
# ROI processed [51/334]
# ROI processed [52/334]
# ROI processed [53/334]
# ROI processed [54/334]
# ROI processed [55/334]
# ROI processed [56/334]
# ROI processed [57/334]
# ROI processed [58/334]
# ROI processed [59/334]
# ROI processed [60/334]
# ROI processed [61/334]
# ROI processed [62/334]
# ROI processed [63/334]
# ROI processed [64/334]
# ROI processed [65/334]
# ROI processed [66/334]
# ROI processed [67/334]
# ROI processed [68/334]
# ROI processed [69/334]
# ROI processed [70/334]
# ROI processed [71/334]
# ROI processed [72/334]
# ROI processed [73/334]
# ROI processed [74/334]
# ROI processed [75/334]
# ROI processed [76/334]
# ROI processed [77/334]
# ROI processed [78/334]
# ROI processed [79/334]
# ROI processed [80/334]
# ROI processed [81/334]
# ROI processed [82/334]
# ROI processed [83/334]
# ROI processed [84/334]
# ROI processed [85/334]
# ROI processed [86/334]
# ROI processed [87/334]
# ROI processed [88/334]
# ROI processed [89/334]
# ROI processed [90/334]
# ROI processed [91/334]
# ROI processed [92/334]
# ROI processed [93/334]
# ROI processed [94/334]
# ROI processed [95/334]
# ROI processed [96/334]
# ROI processed [97/334]
# ROI processed [98/334]
# ROI processed [99/334]
# ROI processed [100/334]
# ROI processed [101/334]
# ROI processed [102/334]
# ROI processed [103/334]
# ROI processed [104/334]
# ROI processed [105/334]
# ROI processed [106/334]
# ROI processed [107/334]
# ROI processed [108/334]
# ROI processed [109/334]
# ROI processed [110/334]
# ROI processed [111/334]
# ROI processed [112/334]
# ROI processed [113/334]
# ROI processed [114/334]
# ROI processed [115/334]
# ROI processed [116/334]
# ROI processed [117/334]
# ROI processed [118/334]
# ROI processed [119/334]
# ROI processed [120/334]
# ROI processed [121/334]
# ROI processed [122/334]
# ROI processed [123/334]
# ROI processed [124/334]
# ROI processed [125/334]
# ROI processed [126/334]
# ROI processed [127/334]
# ROI processed [128/334]
# ROI processed [129/334]
# ROI processed [130/334]
# ROI processed [131/334]
# ROI processed [132/334]
# ROI processed [133/334]
# ROI processed [134/334]
# ROI processed [135/334]
# ROI processed [136/334]
# ROI processed [137/334]
# ROI processed [138/334]
# ROI processed [139/334]
# ROI processed [140/334]
# ROI processed [141/334]
# ROI processed [142/334]
# ROI processed [143/334]
# ROI processed [144/334]
# ROI processed [145/334]
# ROI processed [146/334]
# ROI processed [147/334]
# ROI processed [148/334]
# ROI processed [149/334]
# ROI processed [150/334]
# ROI processed [151/334]
# ROI processed [152/334]
# ROI processed [153/334]
# ROI processed [154/334]
# ROI processed [155/334]
# ROI processed [156/334]
# ROI processed [157/334]
# ROI processed [158/334]
# ROI processed [159/334]
# ROI processed [160/334]
# ROI processed [161/334]
# ROI processed [162/334]
# ROI processed [163/334]
# ROI processed [164/334]
# ROI processed [165/334]
# ROI processed [166/334]
# ROI processed [167/334]
# ROI processed [168/334]
# ROI processed [169/334]
# ROI processed [170/334]
# ROI processed [171/334]
# ROI processed [172/334]
# ROI processed [173/334]
# ROI processed [174/334]
# ROI processed [175/334]
# ROI processed [176/334]
# ROI processed [177/334]
# ROI processed [178/334]
# ROI processed [179/334]
# ROI processed [180/334]
# ROI processed [181/334]
# ROI processed [182/334]
# ROI processed [183/334]
# ROI processed [184/334]
# ROI processed [185/334]
# ROI processed [186/334]
# ROI processed [187/334]
# ROI processed [188/334]
# ROI processed [189/334]
# ROI processed [190/334]
# ROI processed [191/334]
# ROI processed [192/334]
# ROI processed [193/334]
# ROI processed [194/334]
# ROI processed [195/334]
# ROI processed [196/334]
# ROI processed [197/334]
# ROI processed [198/334]
# ROI processed [199/334]
# ROI processed [200/334]
# ROI processed [201/334]
# ROI processed [202/334]
# ROI processed [203/334]
# ROI processed [204/334]
# ROI processed [205/334]
# ROI processed [206/334]
# ROI processed [207/334]
# ROI processed [208/334]
# ROI processed [209/334]
# ROI processed [210/334]
# ROI processed [211/334]
# ROI processed [212/334]
# ROI processed [213/334]
# ROI processed [214/334]
# ROI processed [215/334]
# ROI processed [216/334]
# ROI processed [217/334]
# ROI processed [218/334]
# ROI processed [219/334]
# ROI processed [220/334]
# ROI processed [221/334]
# ROI processed [222/334]
# ROI processed [223/334]
# ROI processed [224/334]
# ROI processed [225/334]
# ROI processed [226/334]
# ROI processed [227/334]
# ROI processed [228/334]
# ROI processed [229/334]
# ROI processed [230/334]
# ROI processed [231/334]
# ROI processed [232/334]
# ROI processed [233/334]
# ROI processed [234/334]
# ROI processed [235/334]
# ROI processed [236/334]
# ROI processed [237/334]
# ROI processed [238/334]
# ROI processed [239/334]
# ROI processed [240/334]
# ROI processed [241/334]
# ROI processed [242/334]
# ROI processed [243/334]
# ROI processed [244/334]
# ROI processed [245/334]
# ROI processed [246/334]
# ROI processed [247/334]
# ROI processed [248/334]
# ROI processed [249/334]
# ROI processed [250/334]
# ROI processed [251/334]
# ROI processed [252/334]
# ROI processed [253/334]
# ROI processed [254/334]
# ROI processed [255/334]
# ROI processed [256/334]
# ROI processed [257/334]
# ROI processed [258/334]
# ROI processed [259/334]
# ROI processed [260/334]
# ROI processed [261/334]
# ROI processed [262/334]
# ROI processed [263/334]
# ROI processed [264/334]
# ROI processed [265/334]
# ROI processed [266/334]
# ROI processed [267/334]
# ROI processed [268/334]
# ROI processed [269/334]
# ROI processed [270/334]
# ROI processed [271/334]
# ROI processed [272/334]
# ROI processed [273/334]
# ROI processed [274/334]
# ROI processed [275/334]
# ROI processed [276/334]
# ROI processed [277/334]
# ROI processed [278/334]
# ROI processed [279/334]
# ROI processed [280/334]
# ROI processed [281/334]
# ROI processed [282/334]
# ROI processed [283/334]
# ROI processed [284/334]
# ROI processed [285/334]
# ROI processed [286/334]
# ROI processed [287/334]
# ROI processed [288/334]
# ROI processed [289/334]
# ROI processed [290/334]
# ROI processed [291/334]
# ROI processed [292/334]
# ROI processed [293/334]
# ROI processed [294/334]
# ROI processed [295/334]
# ROI processed [296/334]
# ROI processed [297/334]
# ROI processed [298/334]
# ROI processed [299/334]
# ROI processed [300/334]
# ROI processed [301/334]
# ROI processed [302/334]
# ROI processed [303/334]
# ROI processed [304/334]
# ROI processed [305/334]
# ROI processed [306/334]
# ROI processed [307/334]
# ROI processed [308/334]
# ROI processed [309/334]
# ROI processed [310/334]
# ROI processed [311/334]
# ROI processed [312/334]
# ROI processed [313/334]
# ROI processed [314/334]
# ROI processed [315/334]
# ROI processed [316/334]
# ROI processed [317/334]
# ROI processed [318/334]
# ROI processed [319/334]
# ROI processed [320/334]
# ROI processed [321/334]
# ROI processed [322/334]
# ROI processed [323/334]
# ROI processed [324/334]
# ROI processed [325/334]
# ROI processed [326/334]
# ROI processed [327/334]
# ROI processed [328/334]
# ROI processed [329/334]
# ROI processed [330/334]
# ROI processed [331/334]
# ROI processed [332/334]
# ROI processed [333/334]
# ROI processed [334/334]

# %%
crop_detected_objects(model1_result_dir + 'val/', obj_val_dir)
# Out:
# ROI processed [1/71]
# ROI processed [2/71]
# ROI processed [3/71]
# ROI processed [4/71]
# ROI processed [5/71]
# ROI processed [6/71]
# ROI processed [7/71]
# ROI processed [8/71]
# ROI processed [9/71]
# ROI processed [10/71]
# ROI processed [11/71]
# ROI processed [12/71]
# ROI processed [13/71]
# ROI processed [14/71]
# ROI processed [15/71]
# ROI processed [16/71]
# ROI processed [17/71]
# ROI processed [18/71]
# ROI processed [19/71]
# ROI processed [20/71]
# ROI processed [21/71]
# ROI processed [22/71]
# ROI processed [23/71]
# ROI processed [24/71]
# ROI processed [25/71]
# ROI processed [26/71]
# ROI processed [27/71]
# ROI processed [28/71]
# ROI processed [29/71]
# ROI processed [30/71]
# ROI processed [31/71]
# ROI processed [32/71]
# ROI processed [33/71]
# ROI processed [34/71]
# ROI processed [35/71]
# ROI processed [36/71]
# ROI processed [37/71]
# ROI processed [38/71]
# ROI processed [39/71]
# ROI processed [40/71]
# ROI processed [41/71]
# ROI processed [42/71]
# ROI processed [43/71]
# ROI processed [44/71]
# ROI processed [45/71]
# ROI processed [46/71]
# ROI processed [47/71]
# ROI processed [48/71]
# ROI processed [49/71]
# ROI processed [50/71]
# ROI processed [51/71]
# ROI processed [52/71]
# ROI processed [53/71]
# ROI processed [54/71]
# ROI processed [55/71]
# ROI processed [56/71]
# ROI processed [57/71]
# ROI processed [58/71]
# ROI processed [59/71]
# ROI processed [60/71]
# ROI processed [61/71]
# ROI processed [62/71]
# ROI processed [63/71]
# ROI processed [64/71]
# ROI processed [65/71]
# ROI processed [66/71]
# ROI processed [67/71]
# ROI processed [68/71]
# ROI processed [69/71]
# ROI processed [70/71]
# ROI processed [71/71]
