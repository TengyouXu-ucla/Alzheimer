# %%
import torch
import torchvision
import os

tile_size = 512

parent_dir = "rois2/"
img_dir = parent_dir + "images/"
tile_dir = parent_dir + "tiles/"
model_dir = parent_dir + "models/"

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
def calculate_iou(box1, box2):
    """
    Calculate the Intersection over Union (IoU) of two bounding boxes.
    
    Parameters:
    box1, box2: Arrays or lists in the format [x_min, y_min, x_max, y_max]
    
    Returns:
    float: IoU value
    """
    x1_min, y1_min, x1_max, y1_max = box1
    x2_min, y2_min, x2_max, y2_max = box2
    
    # Calculate the intersection coordinates
    x_min = max(x1_min, x2_min)
    y_min = max(y1_min, y2_min)
    x_max = min(x1_max, x2_max)
    y_max = min(y1_max, y2_max)
    
    # Calculate the intersection area
    intersection_area = max(0, x_max - x_min) * max(0, y_max - y_min)
    
    # Calculate the area of both boxes
    box1_area = (x1_max - x1_min) * (y1_max - y1_min)
    box2_area = (x2_max - x2_min) * (y2_max - y2_min)
    
    # Calculate the union area
    union_area = box1_area + box2_area - intersection_area
    
    # Calculate the IoU
    iou = intersection_area / union_area
    
    return iou

# %%
def check_pred_boxes(pred_boxes, true_boxes): # both should be tensors - [N, x1, y1, x2, y2]
    check_list = [0] * true_boxes.shape[0]
    for i in range(pred_boxes.shape[0]):
        for j in range(true_boxes.shape[0]):
            if calculate_iou(pred_boxes[i], true_boxes[j]) > 0.5:
                check_list[j] = 1
    return sum(check_list), len(check_list) # return # of true positives and total # of true boxes

# %%
import time
class Timer:
    def __init__(self):
        self.start_time = None
        self.end_time = None

    def start(self):
        self.start_time = time.time()

    def stop(self):
        self.end_time = time.time()

    def elapsed_time(self):
        if self.start_time is None:
            raise ValueError("Timer has not been started.")
        if self.end_time is None:
            raise ValueError("Timer has not been stopped.")

        elapsed_seconds = self.end_time - self.start_time
        hours = int(elapsed_seconds // 3600)
        elapsed_seconds %= 3600
        minutes = int(elapsed_seconds // 60)
        seconds = elapsed_seconds % 60

        return str(f"Elapsed time: {hours} hours, {minutes} minutes, {seconds:.2f} seconds")

# %% [markdown]
# load dataset from pkl

# %%
from torch.utils.data import Dataset, DataLoader
import albumentations as A
import numpy as np
import re
import cv2

with open(tile_dir + 'mean_std.txt') as f:
    lines = f.readlines()
    
mean = []
std = []

for line in lines:
    if line.startswith("Mean: "):
        # Extract the numbers using regex
        numbers_str = re.findall(r'\[([0-9.\s]+)\]', line)[0]
        # Convert the string of numbers to a list of floats
        mean = np.fromstring(numbers_str, sep=' ').tolist()
    if line.startswith("Standard Deviation: "):
        # Extract the numbers using regex
        numbers_str = re.findall(r'\[([0-9.\s]+)\]', line)[0]
        # Convert the string of numbers to a list of floats
        std = np.fromstring(numbers_str, sep=' ').tolist()
print(mean)
print(std)

print(type(mean))

transform = A.Compose([
    # A.augmentations.geometric.rotate.Rotate(limit=15, p=0.5),
    # A.Perspective(scale=[0, 0.1], keep_size=False, fit_output=False, p=1),
    # # A.Resize(224, 224),
    # A.HorizontalFlip(p=0.5),
    # A.GaussNoise(var_limit=(10.0, 50.0), mean=0),
    # # A.RandomToneCurve(scale=0.5, p=1),
    A.Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
    # ClipCoords(), 
    # ToTensorV2()
], bbox_params=A.BboxParams(format='pascal_voc', min_area=1024, min_visibility=0.1, label_fields=['class_labels']))


def custom_collate_fn(batch):
    return list(batch)

class InputDataset(Dataset):

    def __init__(self, inputs_list):
       
        self.inputs_list = inputs_list

    def __len__(self):
        return len(self.inputs_list)

    def __getitem__(self, idx):
        
        img = cv2.imread(self.inputs_list[idx]['image'])
        # print(self.inputs_list[idx]['image'])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img_aug = transform(image = img, bboxes = self.inputs_list[idx]['target']['boxes'], class_labels = self.inputs_list[idx]['target']['labels'])['image']
        
        # img = img.permute(1,2,0)
        boxes = self.inputs_list[idx]['target']['boxes']
        labels = self.inputs_list[idx]['target']['labels']
        # clipped_boxes = torch.clamp(boxes, 0, 1)
        # transformed = transform(image = img, bboxes = clipped_boxes, labels = self.inputs_list[idx]['target']['labels'])
        
        # transformed_image = transformed['image']
        # transformed_bboxes = transformed['bboxes' ]
        # transformed_labels = transformed['labels']
        
        targets = {'boxes': (torch.tensor(boxes, dtype=torch.float64)), 'labels': torch.tensor(labels, dtype=torch.int64)}
        
        
        return {'image': img_aug, 'target': targets}
# Out:
# [0.63990641, 0.67864856, 0.74857624]
# [0.23133176, 0.20776166, 0.17692773]
# <class 'list'>

# %%
def trainModel(model, parent_dir, train_dataloader,val_dataloader, epochs_num): 
    timer = Timer()
    timer.start()
    # Defining the optimizer - adamw
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.01)
    
    # learning rate scheduler - CosineAnnealingLR
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50, eta_min=1e-6)
    
    num_of_epochs = epochs_num
    # Creating a directory for storing models
    model_dir = parent_dir + 'models/'
    if not os.path.exists(model_dir):
        os.mkdir(model_dir)
    
        
    
    for epoch in range(num_of_epochs):
        model.train()
        print('Training started')
        batch_num = 0
        for batch in train_dataloader: # dataloader here, with collate function
            imgs = []
            targets = []
            for item in batch:
                imgs.append(torch.tensor(item['image']).permute(2,0,1).to(device))
                targets.append({'boxes':item['target']['boxes'].to(device), 'labels':item['target']['labels'].to(device)})
            
            # Sets the gradients of all optimized tensors to zero
            optimizer.zero_grad()
            # print('img len:', len(imgs), imgs[0].shape)
            # print('target len:', len(targets))
            result = model(imgs, targets)
   
            batch_num += 1
            # print('result updated')
            # pred - Dict[Tensor], containing classificaiton and regression losses
            # print(batch, '\n')
            # print(result)
            
            bbox_loss = result['bbox_regression']
            # class_loss  = (result['classification'], targets[0]['labels'])
            
            loss = torch.sum(bbox_loss)
            loss.backward()
            optimizer.step()
            scheduler.step()
            
            
            timer.stop()
            
            if batch_num % 50 == 0:
                print("     Epoch: ", epoch+1
                      , " train batch:", batch_num, " time: ", (timer.elapsed_time()), " bbox loss: ", bbox_loss)
            # print("     Epoch: ", epoch+1, " train batch:", batch_num, " time: ", (total_time)/1000, " bbox loss: ", bbox_loss)
                
        # save model for each epoch
        model_path = model_dir + 'model_epoch' + str(epoch + 1) + '.pth'
        torch.save(model.state_dict(), model_path)
        
        # evaluate the model
        iou_thr = 0.5
        score_thr = 0
        
        model.eval()
        print('Validation started')
        true_positive_cnt = 0
        total_cnt = 0
        with torch.no_grad():
            batch_num = 0
            for batch in val_dataloader: # dataloader here, with collate function
                imgs = []
                targets = []
                for item in batch:
                    imgs.append(torch.tensor(item['image']).permute(2,0,1).to(device))
                    targets.append({'boxes':item['target']['boxes'].to(device), 'labels':item['target']['labels'].to(device)})
                        
                preds = model(imgs)      
                batch_num += 1
                for i, img_pred in enumerate(preds):
                    filtered_idx = torchvision.ops.nms(img_pred['boxes'], img_pred['scores'], iou_thr)
                    target = targets[i]
                    tp, tot = check_pred_boxes(img_pred['boxes'][filtered_idx], target['boxes'])
                    true_positive_cnt += tp
                    total_cnt += tot
                recall = true_positive_cnt / total_cnt
                timer.stop()
                if batch_num % 50 == 0:
                    print("     Epoch: ", epoch+1, " validation batch:", batch_num, " time: ", (timer.elapsed_time()), " current recall: ", recall)
        # print("     Epoch: ", epoch+1, " recall: ", recall)
 
        torch.cuda.empty_cache()

# %%
import pickle
train_dataloader = pickle.load(open(model_dir + 'train_dataloader.pkl', 'rb'))
val_dataloader = pickle.load(open(model_dir + 'val_dataloader.pkl', 'rb'))

# %%
model = torchvision.models.detection.ssdlite320_mobilenet_v3_large(num_classes=2)
model = model.to('cuda')

trainModel(model, model_dir, train_dataloader, val_dataloader, 10)
# Out:
# Training started
# C:\Users\Tengyou Xu\AppData\Local\Temp\ipykernel_21172\2067014552.py:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   targets = {'boxes': (torch.tensor(boxes, dtype=torch.float64)), 'labels': torch.tensor(labels, dtype=torch.int64)}
#      Epoch:  1  train batch: 50  time:  Elapsed time: 0 hours, 0 minutes, 13.68 seconds  bbox loss:  tensor(1.5968, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 100  time:  Elapsed time: 0 hours, 0 minutes, 27.36 seconds  bbox loss:  tensor(1.0294, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 150  time:  Elapsed time: 0 hours, 0 minutes, 41.67 seconds  bbox loss:  tensor(0.8714, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 200  time:  Elapsed time: 0 hours, 0 minutes, 55.93 seconds  bbox loss:  tensor(1.2293, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 250  time:  Elapsed time: 0 hours, 1 minutes, 10.28 seconds  bbox loss:  tensor(0.6762, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 300  time:  Elapsed time: 0 hours, 1 minutes, 24.40 seconds  bbox loss:  tensor(0.9341, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 350  time:  Elapsed time: 0 hours, 1 minutes, 38.60 seconds  bbox loss:  tensor(0.8841, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 400  time:  Elapsed time: 0 hours, 1 minutes, 52.86 seconds  bbox loss:  tensor(0.9166, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 450  time:  Elapsed time: 0 hours, 2 minutes, 7.05 seconds  bbox loss:  tensor(0.7871, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 500  time:  Elapsed time: 0 hours, 2 minutes, 21.16 seconds  bbox loss:  tensor(0.6531, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 550  time:  Elapsed time: 0 hours, 2 minutes, 35.46 seconds  bbox loss:  tensor(0.7410, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 600  time:  Elapsed time: 0 hours, 2 minutes, 49.73 seconds  bbox loss:  tensor(0.7109, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 650  time:  Elapsed time: 0 hours, 3 minutes, 4.08 seconds  bbox loss:  tensor(0.9919, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 700  time:  Elapsed time: 0 hours, 3 minutes, 18.36 seconds  bbox loss:  tensor(0.7994, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 750  time:  Elapsed time: 0 hours, 3 minutes, 32.44 seconds  bbox loss:  tensor(0.6070, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 800  time:  Elapsed time: 0 hours, 3 minutes, 46.46 seconds  bbox loss:  tensor(1.1835, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  1  train batch: 850  time:  Elapsed time: 0 hours, 4 minutes, 0.53 seconds  bbox loss:  tensor(0.9251, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
# Validation started
#      Epoch:
device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  8  train batch: 500  time:  Elapsed time: 2 hours, 11 minutes, 49.49 seconds  bbox loss:  tensor(0.2263, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  8  train batch: 550  time:  Elapsed time: 2 hours, 12 minutes, 17.74 seconds  bbox loss:  tensor(0.3689, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  8  train batch: 600  time:  Elapsed time: 2 hours, 12 minutes, 46.39 seconds  bbox loss:  tensor(0.3125, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  8  train batch: 650  time:  Elapsed time: 2 hours, 13 minutes, 15.06 seconds  bbox loss:  tensor(0.3102, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  8  train batch: 700  time:  Elapsed time: 2 hours, 13 minutes, 43.86 seconds  bbox loss:  tensor(0.3219, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  8  train batch: 750  time:  Elapsed time: 2 hours, 14 minutes, 11.44 seconds  bbox loss:  tensor(0.2560, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  8  train batch: 800  time:  Elapsed time: 2 hours, 14 minutes, 38.99 seconds  bbox loss:  tensor(0.3467, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  8  train batch: 850  time:  Elapsed time: 2 hours, 15 minutes, 6.67 seconds  bbox loss:  tensor(0.3999, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
# Validation started
#      Epoch:  8  validation batch: 50  time:  Elapsed time: 2 hours, 17 minutes, 41.38 seconds  current recall:  0.918444165621079
#      Epoch:  8  validation batch: 100  time:  Elapsed time: 2 hours, 20 minutes, 6.79 seconds  current recall:  0.9150409062303335
#      Epoch:  8  validation batch: 150  time:  Elapsed time: 2 hours, 22 minutes, 33.37 seconds  current recall:  0.9107666527021365
#      Epoch:  8  validation batch: 200  time:  Elapsed time: 2 hours, 24 minutes, 54.24 seconds  current recall:  0.9109980928162746
#      Epoch:  8  validation batch: 250  time:  Elapsed time: 2 hours, 27 minutes, 8.42 seconds  current recall:  0.910953706046041
# Training started
#      Epoch:  9  train batch: 50  time:  Elapsed time: 2 hours, 28 minutes, 51.10 seconds  bbox loss:  tensor(0.2287, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 100  time:  Elapsed time: 2 hours, 29 minutes, 4.59 seconds  bbox loss:  tensor(0.2683, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 150  time:  Elapsed time: 2 hours, 29 minutes, 18.16 seconds  bbox loss:  tensor(0.2016, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 200  time:  Elapsed time: 2 hours, 29 minutes, 31.75 seconds  bbox loss:  tensor(0.1985, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 250  time:  Elapsed time: 2 hours, 29 minutes, 45.35 seconds  bbox loss:  tensor(0.3390, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 300  time:  Elapsed time: 2 hours, 29 minutes, 58.97 seconds  bbox loss:  tensor(0.2314, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 350  time:  Elapsed time: 2 hours, 30 minutes, 12.80 seconds  bbox loss:  tensor(0.2562, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 400  time:  Elapsed time: 2 hours, 30 minutes, 26.53 seconds  bbox loss:  tensor(0.2143, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 450  time:  Elapsed time: 2 hours, 30 minutes, 40.36 seconds  bbox loss:  tensor(0.1246, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 500  time:  Elapsed time: 2 hours, 30 minutes, 54.25 seconds  bbox loss:  tensor(0.2636, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 550  time:  Elapsed time: 2 hours, 31 minutes, 8.21 seconds  bbox loss:  tensor(0.2046, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 600  time:  Elapsed time: 2 hours, 31 minutes, 22.33 seconds  bbox loss:  tensor(0.1883, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 650  time:  Elapsed time: 2 hours, 31 minutes, 36.49 seconds  bbox loss:  tensor(0.3402, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 700  time:  Elapsed time: 2 hours, 31 minutes, 50.94 seconds  bbox loss:  tensor(0.2750, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 750  time:  Elapsed time: 2 hours, 32 minutes, 5.49 seconds  bbox loss:  tensor(0.2293, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 800  time:  Elapsed time: 2 hours, 32 minutes, 20.20 seconds  bbox loss:  tensor(0.3576, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  9  train batch: 850  time:  Elapsed time: 2 hours, 32 minutes, 35.14 seconds  bbox loss:  tensor(0.2164, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
# Validation started
#      Epoch:  9  validation batch: 50  time:  Elapsed time: 2 hours, 34 minutes, 1.95 seconds  current recall:  0.9305210918114144
#      Epoch:  9  validation batch: 100  time:  Elapsed time: 2 hours, 35 minutes, 22.04 seconds  current recall:  0.9188679245283019
#      Epoch:  9  validation batch: 150  time:  Elapsed time: 2 hours, 36 minutes, 39.84 seconds  current recall:  0.9182549767047861
#      Epoch:  9  validation batch: 200  time:  Elapsed time: 2 hours, 38 minutes, 0.44 seconds  current recall:  0.9172479391249208
#      Epoch:  9  validation batch: 250  time:  Elapsed time: 2 hours, 39 minutes, 21.47 seconds  current recall:  0.9216284987277353
# Training started
#      Epoch:  10  train batch: 50  time:  Elapsed time: 2 hours, 41 minutes, 31.67 seconds  bbox loss:  tensor(0.1224, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 100  time:  Elapsed time: 2 hours, 41 minutes, 59.21 seconds  bbox loss:  tensor(0.1572, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 150  time:  Elapsed time: 2 hours, 42 minutes, 26.75 seconds  bbox loss:  tensor(0.4135, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 200  time:  Elapsed time: 2 hours, 42 minutes, 54.40 seconds  bbox loss:  tensor(0.2149, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 250  time:  Elapsed time: 2 hours, 43 minutes, 22.20 seconds  bbox loss:  tensor(0.1503, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 300  time:  Elapsed time: 2 hours, 43 minutes, 49.80 seconds  bbox loss:  tensor(0.3215, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 350  time:  Elapsed time: 2 hours, 44 minutes, 17.62 seconds  bbox loss:  tensor(0.1421, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 400  time:  Elapsed time: 2 hours, 44 minutes, 45.58 seconds  bbox loss:  tensor(0.1795, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 450  time:  Elapsed time: 2 hours, 45 minutes, 13.60 seconds  bbox loss:  tensor(0.2503, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 500  time:  Elapsed time: 2 hours, 45 minutes, 41.60 seconds  bbox loss:  tensor(0.2778, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 550  time:  Elapsed time: 2 hours, 46 minutes, 9.70 seconds  bbox loss:  tensor(0.1533, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 600  time:  Elapsed time: 2 hours, 46 minutes, 37.93 seconds  bbox loss:  tensor(0.2551, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 650  time:  Elapsed time: 2 hours, 47 minutes, 6.42 seconds  bbox loss:  tensor(0.3043, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 700  time:  Elapsed time: 2 hours, 47 minutes, 34.89 seconds  bbox loss:  tensor(0.2829, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 750  time:  Elapsed time: 2 hours, 48 minutes, 3.46 seconds  bbox loss:  tensor(0.4012, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 800  time:  Elapsed time: 2 hours, 48 minutes, 31.94 seconds  bbox loss:  tensor(0.2000, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
#      Epoch:  10  train batch: 850  time:  Elapsed time: 2 hours, 49 minutes, 0.46 seconds  bbox loss:  tensor(0.2947, device='cuda:0', dtype=torch.float64, grad_fn=<DivBackward0>)
# Validation started
#      Epoch:  10  validation batch: 50  time:  Elapsed time: 2 hours, 51 minutes, 25.94 seconds  current recall:  0.9191655801825294
#      Epoch:  10  validation batch: 100  time:  Elapsed time: 2 hours, 54 minutes, 2.01 seconds  current recall:  0.9238156209987196
#      Epoch:  10  validation batch: 150  time:  Elapsed time: 2 hours, 56 minutes, 35.29 seconds  current recall:  0.9267979452054794
#      Epoch:  10  validation batch: 200  time:  Elapsed time: 2 hours, 59 minutes, 11.40 seconds  current recall:  0.9248240563019834
#      Epoch:  10  validation batch: 250  time:  Elapsed time: 3 hours, 1 minutes, 49.89 seconds  current recall:  0.9273189326556543
