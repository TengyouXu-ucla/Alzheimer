# %% [markdown]
# Another model to predict the type of each plaque in the rois
# Model: EfficientNet (B1/B2) - a type of CNN
#   - Input: cropped images of plaques (cropped according to the bounding box)
#   - Output: type of each plaque
#
# Model format (EfficientNet B2):
#   - Input: (N, 3, 260, 260) - (batch size, C, H, W)
#   - Output: (1, # of classes)

# %%
import torch
import torchvision
import os
import cv2
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, models, transforms
from utils import im_to_txt_path, imread, isfile, imwrite
from dataset_operations import clip_value
import pickle


parent_dir = 'rois2/'
object_dir = parent_dir + 'objects/'
img_dir = parent_dir + 'images/'
label_dir = parent_dir + 'labels/'
model_dir = parent_dir + 'models/'
tile_dir = parent_dir + 'tiles/'

obj_train_dir = object_dir + 'train/'
obj_val_dir = object_dir + 'val'
false_positive_label_dir = tile_dir + '/false_positives/labels/'
if not os.path.exists(object_dir):
    os.makedirs(object_dir)

# %%
class_num = 2

# %%
# clean up the directory
for dir, subdirs, files in os.walk(obj_train_dir):
    for file in files:
        os.remove(os.path.join(dir, file))

for dir, subdirs, files in os.walk(obj_val_dir):
    for file in files:
        os.remove(os.path.join(dir, file))            

if os.path.exists(obj_train_dir):       
    for dir in os.listdir(obj_train_dir):
        os.removedirs(obj_train_dir + dir)
        
if os.path.exists(obj_val_dir):
    for dir in os.listdir(obj_val_dir):
        os.removedirs(obj_val_dir + dir)

# %%
train_roi_paths = []
if isfile(img_dir + 'train_rois.txt'):
    with open(img_dir + 'train_rois.txt', 'r') as f:
        train_roi_paths = f.read().splitlines()
print(len(train_roi_paths))

val_roi_paths = []
if isfile(img_dir + 'val_rois.txt'):
    with open(img_dir + 'val_rois.txt', 'r') as f:
        val_roi_paths = f.read().splitlines()
print(len(val_roi_paths))

test_roi_paths = []
if isfile(img_dir + 'test_rois.txt'):
    with open(img_dir + 'test_rois.txt', 'r') as f:
        test_roi_paths = f.read().splitlines()
print(len(test_roi_paths))
# Out:
# 334
# 71
# 71

# %%
print(len(train_roi_paths + val_roi_paths + test_roi_paths))
# Out:
# 476

# %% [markdown]
# Calculate mean and std for each ROI

# %%
def calculate_mean_std_ROI(roi_paths):
    mean_std = {}
    mean = 0
    std = 0
    for roi_path in roi_paths:
        roi_name = roi_path.split('/')[-1].split('.')[0]    
        img = imread(roi_path)
        pixels = img.shape[0] * img.shape[1]
        temp_img = img / 255.0
        mean = np.sum(temp_img, axis=(0, 1)) / pixels
        std = np.sqrt(np.sum(temp_img ** 2, axis=(0, 1)) / pixels - mean ** 2)
        mean_std[roi_name] = (mean, std)
    return mean_std

# %%
# mean_std = calculate_mean_std_ROI(train_roi_paths + val_roi_paths + test_roi_paths)
# with open(img_dir + 'mean_std.pkl', 'wb') as f:
#     pickle.dump(mean_std, f)

# %%
mean_std = pickle.load(open(img_dir + 'mean_std.pkl', 'rb'))
print(len(mean_std))
# Out:
# 476

# %% [markdown]
# Crop objects from ground truth bounding boxes

# %%
def crop_positive_objects(roi_paths, outer_size_percent, save_dir, class_num = 2):
    tot_num = 0
    for roi_fp in roi_paths:
        roi_name = roi_fp.split('/')[-1].split('.')[0]
        if isfile(im_to_txt_path(roi_fp)):
            roi_img = imread(roi_fp).copy()
            lines = open(im_to_txt_path(roi_fp), 'r').readlines()
            for line in lines:
                line = line.split()
                x1,y1,x2,y2 = int(line[1]), int(line[2]), int(line[3]), int(line[4])
                pixel_outter_x = int((x2 - x1) * outer_size_percent)
                pixel_outter_y = int((y2 - y1) * outer_size_percent)
                x1 = clip_value(x1 - pixel_outter_x, 0, roi_img.shape[1])
                y1 = clip_value(y1 - pixel_outter_y, 0, roi_img.shape[0])
                x2 = clip_value(x2 + pixel_outter_x, 0, roi_img.shape[1])
                y2 = clip_value(y2 + pixel_outter_y, 0, roi_img.shape[0])
                if class_num == 3:  
                    type = str(line[0])
                elif class_num == 2:
                    type = 'object'
                obj_crop_dir = save_dir + type + '/'
                if not os.path.exists(obj_crop_dir):
                    os.makedirs(obj_crop_dir)
                crop = roi_img[y1:y2,x1:x2]
                filename = roi_name + '__' + str(x1) + '_' + str(y1) + '_' + str(x2) + '_' + str(y2)
                # print(obj_crop_dir + filename + '.png')
                imwrite(obj_crop_dir + filename + '.png', crop)
                tot_num += 1
    return tot_num

# %%
tot_pos_obj_train = crop_positive_objects(train_roi_paths, 0.1, obj_train_dir, class_num)
print('Total number of train positive objects: ', tot_pos_obj_train)
# Out:
# Total number of train positive objects:  14312

# %%
tot_pos_obj_val = crop_positive_objects(test_roi_paths, 0.1, obj_val_dir, class_num)
print('Total number of test positive objects: ', obj_val_dir)
# Out:
# Total number of test positive objects:  2912

# %% [markdown]
# Crop objects from negative bounding boxes

# %%
import random
def crop_negative_objects(roi_paths, save_dir, nega_obj_num, nega_obj_size, mean_std_dict, false_positive_ratio = 0.5):
    # crop negative objects on background
    print('Cropping negative objects on background...')
    for num, roi_path in enumerate(roi_paths):
        img = imread(roi_path).copy()
        roi_name =  roi_path.split('/')[-1].split('.')[0]
        # get mean
        mean = mean_std_dict[roi_name][0]
        # read labels of current roi
        labels = []
        if isfile(im_to_txt_path(roi_path)):
            f = open(im_to_txt_path(roi_path), 'r')
            lines = f.readlines()
            for line in lines:
                line = line.split()
                x1,y1,x2,y2 = int(line[1]), int(line[2]), int(line[3]), int(line[4])
                labels.append([x1,y1,x2,y2])
        # cover true boxes with mean
        for label in labels:
            img[label[1]:label[3], label[0]:label[2]] = mean*255
        # randomly crop 
        for i in range(int(nega_obj_num * false_positive_ratio / len(roi_paths))):
            x1 = np.random.randint(0, img.shape[1] - nega_obj_size)
            y1 = np.random.randint(0, img.shape[0] - nega_obj_size)
            x2 = x1 + nega_obj_size
            y2 = y1 + nega_obj_size
            obj = img[y1:y2, x1:x2]
            filename = roi_name + '__' + str(x1) + '_' + str(y1) + '_' + str(x2) + '_' + str(y2)
            if not os.path.exists(save_dir + 'background/'):
                os.makedirs(save_dir + 'background/')
            imwrite(save_dir + 'background/' + filename + '.png', obj)
        print('     Cropped ROI ', num + 1, '/', len(roi_paths), ' with ', i, ' objects')
    
    # crop false positives
    print('Cropping false positives...')
    for dir, subdirs, files in os.walk(false_positive_label_dir):
        for num, file in enumerate(files):
            
            # read the labels
            labels = open(os.path.join(dir, file), 'r').readlines()
            # read the image
            # print(img_dir + file.split('.')[0] + '.png')
            img = imread(img_dir + file.split('.')[0] + '.png').copy()
            sample_labels = random.sample(labels, int(nega_obj_num * (1 - false_positive_ratio) / len(files)))
            total_num = len(sample_labels)
            for label in sample_labels:
                label = label.split()
                x1,y1,x2,y2 = int(float(label[1])), int(float(label[2])), int(float(label[3])), int(float(label[4]))
                x1 = clip_value(x1, 0, img.shape[1])
                y1 = clip_value(y1, 0, img.shape[0])
                x2 = clip_value(x2, 0, img.shape[1])
                y2 = clip_value(y2, 0, img.shape[0])
                obj = img[y1:y2, x1:x2]
                if not (x2 > x1 and y2 > y1):  
                    total_num -= 1
                    continue
                filename = file.split('.')[0] + '__' + str(x1) + '_' + str(y1) + '_' + str(x2) + '_' + str(y2)
                if not os.path.exists(save_dir + 'background/'):
                    os.makedirs(save_dir + 'background/')
                imwrite(save_dir + 'background/' + filename + '.png',obj)
            print('     Cropped ROI ', num + 1, '/', len(files), ' with ', total_num, ' objects')

# %%
if os.path.exists(obj_train_dir + 'background'):
    for file in os.listdir(obj_train_dir + 'background'):
        os.remove(os.path.join(obj_train_dir + 'background', file))

# %%
crop_negative_objects(train_roi_paths, obj_train_dir, tot_pos_obj_train*5, 260, mean_std, 0.5)
# Out:
# Cropping negative objects on background...
#      Cropped ROI  1 / 334  with  106  objects
#      Cropped ROI  2 / 334  with  106  objects
#      Cropped ROI  3 / 334  with  106  objects
#      Cropped ROI  4 / 334  with  106  objects
#      Cropped ROI  5 / 334  with  106  objects
#      Cropped ROI  6 / 334  with  106  objects
#      Cropped ROI  7 / 334  with  106  objects
#      Cropped ROI  8 / 334  with  106  objects
#      Cropped ROI  9 / 334  with  106  objects
#      Cropped ROI  10 / 334  with  106  objects
#      Cropped ROI  11 / 334  with  106  objects
#      Cropped ROI  12 / 334  with  106  objects
#      Cropped ROI  13 / 334  with  106  objects
#      Cropped ROI  14 / 334  with  106  objects
#      Cropped ROI  15 / 334  with  106  objects
#      Cropped ROI  16 / 334  with  106  objects
#      Cropped ROI  17 / 334  with  106  objects
#      Cropped ROI  18 / 334  with  106  objects
#      Cropped ROI  19 / 334  with  106  objects
#      Cropped ROI  20 / 334  with  106  objects
#      Cropped ROI  21 / 334  with  106  objects
#      Cropped ROI  22 / 334  with  106  objects
#      Cropped ROI  23 / 334  with  106  objects
#      Cropped ROI  24 / 334  with  106  objects
#      Cropped ROI  25 / 334  with  106  objects
#      Cropped ROI  26 / 334  with  106  objects
#      Cropped ROI  27 / 334  with  106  objects
#      Cropped ROI  28 / 334  with  106  objects
#      Cropped ROI  29 / 334  with  106  objects
#      Cropped ROI  30 / 334  with  106  objects
#      Cropped ROI  31 / 334  with  106  objects
#      Cropped ROI  32 / 334  with  106  objects
#      Cropped ROI  33 / 334  with  106  objects
#      Cropped ROI  34 / 334  with  106  objects
#      Cropped ROI  35 / 334  with  106  objects
#      Cropped ROI  36 / 334  with  106  objects
#      Cropped ROI  37 / 334  with  106  objects
#      Cropped ROI  38 / 334  with  106  objects
#      Cropped ROI  39 / 334  with  106  objects
#      Cropped ROI  40 / 334  with  106  objects
#      Cropped ROI  41 / 334  with  106  objects
#      Cropped ROI  42 / 334  with  106  objects
#      Cropped ROI  43 / 334  with  106  objects
#      Cropped ROI  44 / 334  with  106  objects
#      Cropped ROI  45 / 334  with  106  objects
#      Cropped ROI  46 / 334  with  106  objects
#      Cropped ROI  47 / 334  with  106  objects
#      Cropped ROI  48 / 334  with  106  objects
#      Cropped ROI  49 / 334  with  106  objects
#      Cropped ROI  50 / 334  with  106  objects
#      Cropped ROI  51 / 334  with  106  objects
#      Cropped ROI  52 / 334  with  106  objects
#      Cropped ROI  53 / 334  with  106  objects
#      Cropped ROI  54 / 334  with  106  objects
#      Cropped ROI  55 / 334  with  106  objects
#      Cropped ROI  56 / 334  with  106  objects
#      Cropped ROI  57 / 334  with  106  objects
#      Cropped ROI  58 / 334  with  106  objects
#      Cropped ROI  59 / 334  with  106  objects
#      Cropped ROI  60 / 334  with  106  objects
#      Cropped ROI  61 / 334  with  106  objects
#      Cropped ROI  62 / 334  with  106  objects
#      Cropped ROI  63 / 334  with  106  objects
#      Cropped ROI  64 / 334  with  106  objects
#      Cropped ROI  65 / 334  with  106  objects
#      Cropped ROI  66 / 334  with  106  objects
#      Cropped ROI  67 / 334  with  106  objects
#      Cropped ROI  68 / 334  with  106  objects
#      Cropped ROI  69 / 334  with  106  objects
#      Cropped ROI  70 / 334  with  106  objects
#      Cropped ROI  71 / 334  with  106  objects
#      Cropped ROI  72 / 334  with  106  objects
#      Cropped ROI  73 / 334  with  106  objects
#      Cropped ROI  74 / 334  with  106  objects
#      Cropped ROI  75 / 334  with  106  objects
#      Cropped ROI  76 / 334  with  106  objects
#      Cropped ROI  77 / 334  with  106  objects
#      Cropped ROI  78 / 334  with  106  objects
#      Cropped ROI  79 / 334  with  106  objects
#      Cropped ROI  80 / 334  with  106  objects
#      Cropped ROI  81 / 334  with  106  objects
#      Cropped ROI  82 / 334  with  106  objects
#      Cropped ROI  83 / 334  with  106  objects
#      Cropped ROI  84 / 334  with  106  objects
#      Cropped ROI  85 / 334  with  106  objects
#      Cropped ROI  86 / 334  with  106  objects
#      Cropped ROI  87 / 334  with  106  objects
#      Cropped ROI  88 / 334  with  106  objects
#      Cropped ROI  89 / 334  with  106  objects
#      Cropped ROI  90 / 334  with  106  objects
#      Cropped ROI  91 / 334  with  106  objects
#      Cropped ROI  92 / 334  with  106  objects
#      Cropped ROI  93 / 334  with  106  objects
#      Cropped ROI  94 / 334  with  106  objects
#      Cropped ROI  95 / 334  with  106  objects
#      Cropped ROI  96 / 334  with  106  objects
#      Cropped ROI  97 / 334  with  106  objects
#      Cropped ROI  98 / 334  with  106  objects
#      Cropped ROI  99 / 334  with  106  objects
#      Cropped ROI  100 / 334  with  106  objects
#      Cropped ROI  101 / 334  with  106  objects
#      Cropped ROI  102 / 334  with  106  objects
#      Cropped ROI  103 / 334  with  106  objects
#      Cropped ROI  104 / 334  with  106  objects
#      Cropped ROI  105 / 334  with  106  objects
#      Cropped ROI  106 / 334  with  106  objects
#      Cropped ROI  107 / 334  with  106  objects
#      Cropped ROI  108 / 334  with  106  objects
#      Cropped ROI  109 / 334  with  106  objects
#      Cropped ROI  110 / 334  with  106  objects
#      Cropped ROI  111 / 334  with  106  objects
#      Cropped ROI  112 / 334  with  106  objects
#      Cropped ROI  113 / 334  with  106  objects
#      Cropped ROI  114 / 334  with  106  objects
#      Cropped ROI  115 / 334  with  106  objects
#      Cropped ROI  116 / 334  with  106  objects
#      Cropped ROI  117 / 334  with  106  objects
#      Cropped ROI  118 / 334  with  106  objects
#      Cropped ROI  119 / 334  with  106  objects
#      Cropped ROI  120 / 334  with  106  objects
#      Cropped ROI  121 / 334  with  106  objects
#      Cropped ROI  122 / 334  with  106  objects
#      Cropped ROI  123 / 334  with  106  objects
#      Cropped ROI  124 / 334  with  106  objects
#      Cropped ROI  125 / 334  with  106  objects
#      Cropped ROI  126 / 334  with  106  objects
#      Cropped ROI  127 / 334  with  106  objects
#      Cropped ROI  128 / 334  with  106  objects
#      Cropped ROI  129 / 334  with  106  objects
#      Cropped ROI  130 / 334  with  106  objects
#      Cropped ROI  131 / 334  with  106  objects
#      Cropped ROI  132 / 334  with  106  objects
#      Cropped ROI  133 / 334  with  106  objects
#      Cropped ROI  134 / 334  with  106  objects
#      Cropped ROI  135 / 334  with  106  objects
#      Cropped ROI  136 / 334  with  106  objects
#      Cropped ROI  137 / 334  with  106  objects
#      Cropped ROI  138 / 334  with  106  objects
#      Cropped ROI  139 / 334  with  106  objects
#      Cropped ROI  140 / 334  with  106  objects
#      Cropped ROI  141 / 334  with  106  objects
#      Cropped ROI  142 / 334  with  106  objects
#      Cropped ROI  143 / 334  with  106  objects
#      Cropped ROI  144 / 334  with  106  objects
#      Cropped ROI  145 / 334  with  106  objects
#      Cropped ROI  146 / 334  with  106  objects
#      Cropped ROI  147 / 334  with  106  objects
#      Cropped ROI  148 / 334  with  106  objects
#      Cropped ROI  149 / 334  with  106  objects
#      Cropped ROI  150 / 334  with  106  objects
#      Cropped ROI  151 / 334  with  106  objects
#      Cropped ROI  152 / 334  with  106  objects
#      Cropped ROI  153 / 334  with  106  objects
#      Cropped ROI  154 / 334  with  106  objects
#      Cropped ROI  155 / 334  with  106  objects
#      Cropped ROI  156 / 334  with  106  objects
#      Cropped ROI  157 / 334  with  106  objects
#      Cropped ROI  158 / 334  with  106  objects
#      Cropped ROI  159 / 334  with  106  objects
#      Cropped ROI  160 / 334  with  106  objects
#      Cropped ROI  161 / 334  with  106  objects
#      Cropped ROI  162 / 334  with  106  objects
#      Cropped ROI  163 / 334  with  106  objects
#      Cropped ROI  164 / 334  with  106  objects
#      Cropped ROI  165 / 334  with  106  objects
#      Cropped ROI  166 / 334  with  106  objects
#      Cropped ROI  167 / 334  with  106  objects
#      Cropped ROI  168 / 334  with  106  objects
#      Cropped ROI  169 / 334  with  106  objects
#      Cropped ROI  170 / 334  with  106  objects
#      Cropped ROI  171 / 334  with  106  objects
#      Cropped ROI  172 / 334  with  106  objects
#      Cropped ROI  173 / 334  with  106  objects
#      Cropped ROI  174 / 334  with  106  objects
#      Cropped ROI  175 / 334  with  106  objects
#      Cropped ROI  176 / 334  with  106  objects
#      Cropped ROI  177 / 334  with  106  objects
#      Cropped ROI  178 / 334  with  106  objects
#      Cropped ROI  179 / 334  with  106  objects
#      Cropped ROI  180 / 334  with  106  objects
#      Cropped ROI  181 / 334  with  106  objects
#      Cropped ROI  182 / 334  with  106  objects
#      Cropped ROI  183 / 334  with  106  objects
#      Cropped ROI  184 / 334  with  106  objects
#      Cropped ROI  185 / 334  with  106  objects
#      Cropped ROI  186 / 334  with  106  objects
#      Cropped ROI  187 / 334  with  106  objects
#      Cropped ROI  188 / 334  with  106  objects
#      Cropped ROI  189 / 334  with  106  objects
#      Cropped ROI  190 / 334  with  106  objects
#      Cropped ROI  191 / 334  with  106  objects
#      Cropped ROI  192 / 334  with  106  objects
#      Cropped ROI  193 / 334  with  106  objects
#      Cropped ROI  194 / 334  with  106  objects
#      Cropped ROI  195 / 334  with  106  objects
#      Cropped ROI  196 / 334  with  106  objects
#      Cropped ROI  197 / 334  with  106  objects
#      Cropped ROI  198 / 334  with  106  objects
#      Cropped ROI  199 / 334  with  106  objects
#      Cropped ROI  200 / 334  with  106  objects
#      Cropped ROI  201 / 334  with  106  objects
#      Cropped ROI  202 / 334  with  106  objects
#      Cropped ROI  203 / 334  with  106  objects
#      Cropped ROI  204 / 334  with  106  objects
#      Cropped ROI  205 / 334  with  106  objects
#      Cropped ROI  206 / 334  with  106  objects
#      Cropped ROI  207 / 334  with  106  objects
#      Cropped ROI  208 / 334  with  106  objects
#      Cropped ROI  209 / 334  with  106  objects
#      Cropped ROI  210 / 334  with  106  objects
#      Cropped ROI  211 / 334  with  106  objects
#      Cropped ROI  212 / 334  with  106  objects
#      Cropped ROI  213 / 334  with  106  objects
#      Cropped ROI  214 / 334  with  106  objects
#      Cropped ROI  215 / 334  with  106  objects
#      Cropped ROI  216 / 334  with  106  objects
#      Cropped ROI  217 / 334  with  106  objects
#      Cropped ROI  218 / 334  with  106  objects
#      Cropped ROI  219 / 334  with  106  objects
#      Cropped ROI  220 / 334  with  106  objects
#      Cropped ROI  221 / 334  with  106  objects
#      Cropped ROI  222 / 334  with  106  objects
#      Cropped ROI  223 / 334  with  106  objects
#      Cropped ROI  224 / 334  with  106  objects
#      Cropped ROI  225 / 334  with  106  objects
#      Cropped ROI  226 / 334  with  106  objects
#      Cropped ROI  227 / 334  with  106  objects
#      Cropped ROI  228 / 334  with  106  objects
#      Cropped ROI  229 / 334  with  106  objects
#      Cropped ROI  230 / 334  with  106  objects
#      Cropped ROI  231 / 334  with  106  objects
#      Cropped ROI  232 / 334  with  106  objects
#      Cropped ROI  233 / 334  with  106  objects
#      Cropped ROI  234 / 334  with  106  objects
#      Cropped ROI  235 / 334  with  106  objects
#      Cropped ROI  236 / 334  with  106  objects
#      Cropped ROI  237 / 334  with  106  objects
#      Cropped ROI  238 / 334  with  106  objects
#      Cropped ROI  239 / 334  with  106  objects
#      Cropped ROI  240 / 334  with  106  objects
#      Cropped ROI  241 / 334  with  106  objects
#      Cropped ROI  242 / 334  with  106  objects
#      Cropped ROI  243 / 334  with  106  objects
#      Cropped ROI  244 / 334  with  106  objects
#      Cropped ROI  245 / 334  with  106  objects
#      Cropped ROI  246 / 334  with  106  objects
#      Cropped ROI  247 / 334  with  106  objects
#      Cropped ROI  248 / 334  with  106  objects
#      Cropped ROI  249 / 334  with  106  objects
#      Cropped ROI  250 / 334  with  106  objects
#      Cropped ROI  251 / 334  with  106  objects
#      Cropped ROI  252 / 334  with  106  objects
#      Cropped ROI  253 / 334  with  106  objects
#      Cropped ROI  254 / 334  with  106  objects
#      Cropped ROI  255 / 334  with  106  objects
#      Cropped ROI  256 / 334  with  106  objects
#      Cropped ROI  257 / 334  with  106  objects
#      Cropped ROI  258 / 334  with  106  objects
#      Cropped ROI  259 / 334  with  106  objects
#      Cropped ROI  260 / 334  with  106  objects
#      Cropped ROI  261 / 334  with  106  objects
#      Cropped ROI  262 / 334  with  106  objects
#      Cropped ROI  263 / 334  with  106  objects
#      Cropped ROI  264 / 334  with  106  objects
#      Cropped ROI  265 / 334  with  106  objects
#      Cropped ROI  266 / 334  with  106  objects
#      Cropped ROI  267 / 334  with  106  objects
#      Cropped ROI  268 / 334  with  106  objects
#      Cropped ROI  269 / 334  with  106  objects
#      Cropped ROI  270 / 334  with  106  objects
#      Cropped ROI  271 / 334  with  106  objects
#      Cropped ROI  272 / 334  with  106  objects
#      Cropped ROI  273 / 334  with  106  objects
#      Cropped ROI  274 / 334  with  106  objects
#      Cropped ROI  275 / 334  with  106  objects
#      Cropped ROI  276 / 334  with  106  objects
#      Cropped ROI  277 / 334  with  106  objects
#      Cropped ROI  278 / 334  with  106  objects
#      Cropped ROI  279 / 334  with  106  objects
#      Cropped ROI  280 / 334  with  106  objects
#      Cropped ROI  281 / 334  with  106  objects
#      Cropped ROI  282 / 334  with  106  objects
#      Cropped ROI  283 / 334  with  106  objects
#      Cropped ROI  284 / 334  with  106  objects
#      Cropped ROI  285 / 334  with  106  objects
#      Cropped ROI  286 / 334  with  106  objects
#      Cropped ROI  287 / 334  with  106  objects
#      Cropped ROI  288 / 334  with  106  objects
#      Cropped ROI  289 / 334  with  106  objects
#      Cropped ROI  290 / 334  with  106  objects
#      Cropped ROI  291 / 334  with  106  objects
#      Cropped ROI  292 / 334  with  106  objects
#      Cropped ROI  293 / 334  with  106  objects
#      Cropped ROI  294 / 334  with  106  objects
#      Cropped ROI  295 / 334  with  106  objects
#      Cropped ROI  296 / 334  with  106  objects
#      Cropped ROI  297 / 334  with  106  objects
#      Cropped ROI  298 / 334  with  106  objects
#      Cropped ROI  299 / 334  with  106  objects
#      Cropped ROI  300 / 334  with  106  objects
#      Cropped ROI  301 / 334  with  106  objects
#      Cropped ROI  302 / 334  with  106  objects
#      Cropped ROI  303 / 334  with  106  objects
#      Cropped ROI  304 / 334  with  106  objects
#      Cropped ROI  305 / 334  with  106  objects
#      Cropped ROI  306 / 334  with  106  objects
#      Cropped ROI  307 / 334  with  106  objects
#      Cropped ROI  308 / 334  with  106  objects
#      Cropped ROI  309 / 334  with  106  objects
#      Cropped ROI  310 / 334  with  106  objects
#      Cropped ROI  311 / 334  with  106  objects
#      Cropped ROI  312 / 334  with  106  objects
#      Cropped ROI  313 / 334  with  106  objects
#      Cropped ROI  314 / 334  with  106  objects
#      Cropped ROI  315 / 334  with  106  objects
#      Cropped ROI  316 / 334  with  106  objects
#      Cropped ROI  317 / 334  with  106  objects
#      Cropped ROI  318 / 334  with  106  objects
#      Cropped ROI  319 / 334  with  106  objects
#      Cropped ROI  320 / 334  with  106  objects
#      Cropped ROI  321 / 334  with  106  objects
#      Cropped ROI  322 / 334  with  106  objects
#      Cropped ROI  323 / 334  with  106  objects
#      Cropped ROI  324 / 334  with  106  objects
#      Cropped ROI  325 / 334  with  106  objects
#      Cropped ROI  326 / 334  with  106  objects
#      Cropped ROI  327 / 334  with  106  objects
#      Cropped ROI  328 / 334  with  106  objects
#      Cropped ROI  329 / 334  with  106  objects
#      Cropped ROI  330 / 334  with  106  objects
#      Cropped ROI  331 / 334  with  106  objects
#      Cropped ROI  332 / 334  with  106  objects
#      Cropped ROI  333 / 334  with  106  objects
#      Cropped ROI  334 / 334  with  106  objects
# Cropping false positives...
#      Cropped ROI  1 / 66  with  470  objects
#      Cropped ROI  2 / 66  with  481  objects
#      Cropped ROI  3 / 66  with  492  objects
#      Cropped ROI  4 / 66  with  492  objects
#      Cropped ROI  5 / 66  with  433  objects
#      Cropped ROI  6 / 66  with  464  objects
#      Cropped ROI  7 / 66  with  505  objects
#      Cropped ROI  8 / 66  with  484  objects
#      Cropped ROI  9 / 66  with  506  objects
#      Cropped ROI  10 / 66  with  483  objects
#      Cropped ROI  11 / 66  with  494  objects
#      Cropped ROI  12 / 66  with  495  objects
#      Cropped ROI  13 / 66  with  472  objects
#      Cropped ROI  14 / 66  with  492  objects
#      Cropped ROI  15 / 66  with  487  objects
#      Cropped ROI  16 / 66  with  471  objects
#      Cropped ROI  17 / 66  with  492  objects
#      Cropped ROI  18 / 66  with  482  objects
#      Cropped ROI  19 / 66  with  492  objects
#      Cropped ROI  20 / 66  with  508  objects
#      Cropped ROI  21 / 66  with  475  objects
#      Cropped ROI  22 / 66  with  475  objects
#      Cropped ROI  23 / 66  with  488  objects
#      Cropped ROI  24 / 66  with  488  objects
#      Cropped ROI  25 / 66  with  467  objects
#      Cropped ROI  26 / 66  with  500  objects
#      Cropped ROI  27 / 66  with  472  objects
#      Cropped ROI  28 / 66  with  447  objects
#      Cropped ROI  29 / 66  with  479  objects
#      Cropped ROI  30 / 66  with  520  objects
#      Cropped ROI  31 / 66  with  449  objects
#      Cropped ROI  32 / 66  with  443  objects
#      Cropped ROI  33 / 66  with  484  objects
#      Cropped ROI  34 / 66  with  484  objects
#      Cropped ROI  35 / 66  with  495  objects
#      Cropped ROI  36 / 66  with  491  objects
#      Cropped ROI  37 / 66  with  501  objects
#      Cropped ROI  38 / 66  with  497  objects
#      Cropped ROI  39 / 66  with  447  objects
#      Cropped ROI  40 / 66  with  495  objects
#      Cropped ROI  41 / 66  with  477  objects
#      Cropped ROI  42 / 66  with  480  objects
#      Cropped ROI  43 / 66  with  475  objects
#      Cropped ROI  44 / 66  with  475  objects
#      Cropped ROI  45 / 66  with  511  objects
#      Cropped ROI  46 / 66  with  451  objects
#      Cropped ROI  47 / 66  with  478  objects
#      Cropped ROI  48 / 66  with  489  objects
#      Cropped ROI  49 / 66  with  483  objects
#      Cropped ROI  50 / 66  with  500  objects
#      Cropped ROI  51 / 66  with  474  objects
#      Cropped ROI  52 / 66  with  488  objects
#      Cropped ROI  53 / 66  with  512  objects
#      Cropped ROI  54 / 66  with  457  objects
#      Cropped ROI  55 / 66  with  468  objects
#      Cropped ROI  56 / 66  with  522  objects
#      Cropped ROI  57 / 66  with  463  objects
#      Cropped ROI  58 / 66  with  478  objects
#      Cropped ROI  59 / 66  with  460  objects
#      Cropped ROI  60 / 66  with  486  objects
#      Cropped ROI  61 / 66  with  480  objects
#      Cropped ROI  62 / 66  with  475  objects
#      Cropped ROI  63 / 66  with  468  objects
#      Cropped ROI  64 / 66  with  438  objects
#      Cropped ROI  65 / 66  with  458  objects
#      Cropped ROI  66 / 66  with  454  objects

# %%
if os.path.exists(obj_val_dir + 'background'):
    for file in os.listdir(obj_val_dir + 'background'):
        os.remove(os.path.join(obj_val_dir + 'background', file))

# %%
crop_negative_objects(test_roi_paths, obj_val_dir, tot_pos_obj_val*5, 260, mean_std, 0.5)
# Out:
# Cropping negative objects on background...
#      Cropped ROI  1 / 71  with  101  objects
#      Cropped ROI  2 / 71  with  101  objects
#      Cropped ROI  3 / 71  with  101  objects
#      Cropped ROI  4 / 71  with  101  objects
#      Cropped ROI  5 / 71  with  101  objects
#      Cropped ROI  6 / 71  with  101  objects
#      Cropped ROI  7 / 71  with  101  objects
#      Cropped ROI  8 / 71  with  101  objects
#      Cropped ROI  9 / 71  with  101  objects
#      Cropped ROI  10 / 71  with  101  objects
#      Cropped ROI  11 / 71  with  101  objects
#      Cropped ROI  12 / 71  with  101  objects
#      Cropped ROI  13 / 71  with  101  objects
#      Cropped ROI  14 / 71  with  101  objects
#      Cropped ROI  15 / 71  with  101  objects
#      Cropped ROI  16 / 71  with  101  objects
#      Cropped ROI  17 / 71  with  101  objects
#      Cropped ROI  18 / 71  with  101  objects
#      Cropped ROI  19 / 71  with  101  objects
#      Cropped ROI  20 / 71  with  101  objects
#      Cropped ROI  21 / 71  with  101  objects
#      Cropped ROI  22 / 71  with  101  objects
#      Cropped ROI  23 / 71  with  101  objects
#      Cropped ROI  24 / 71  with  101  objects
#      Cropped ROI  25 / 71  with  101  objects
#      Cropped ROI  26 / 71  with  101  objects
#      Cropped ROI  27 / 71  with  101  objects
#      Cropped ROI  28 / 71  with  101  objects
#      Cropped ROI  29 / 71  with  101  objects
#      Cropped ROI  30 / 71  with  101  objects
#      Cropped ROI  31 / 71  with  101  objects
#      Cropped ROI  32 / 71  with  101  objects
#      Cropped ROI  33 / 71  with  101  objects
#      Cropped ROI  34 / 71  with  101  objects
#      Cropped ROI  35 / 71  with  101  objects
#      Cropped ROI  36 / 71  with  101  objects
#      Cropped ROI  37 / 71  with  101  objects
#      Cropped ROI  38 / 71  with  101  objects
#      Cropped ROI  39 / 71  with  101  objects
#      Cropped ROI  40 / 71  with  101  objects
#      Cropped ROI  41 / 71  with  101  objects
#      Cropped ROI  42 / 71  with  101  objects
#      Cropped ROI  43 / 71  with  101  objects
#      Cropped ROI  44 / 71  with  101  objects
#      Cropped ROI  45 / 71  with  101  objects
#      Cropped ROI  46 / 71  with  101  objects
#      Cropped ROI  47 / 71  with  101  objects
#      Cropped ROI  48 / 71  with  101  objects
#      Cropped ROI  49 / 71  with  101  objects
#      Cropped ROI  50 / 71  with  101  objects
#      Cropped ROI  51 / 71  with  101  objects
#      Cropped ROI  52 / 71  with  101  objects
#      Cropped ROI  53 / 71  with  101  objects
#      Cropped ROI  54 / 71  with  101  objects
#      Cropped ROI  55 / 71  with  101  objects
#      Cropped ROI  56 / 71  with  101  objects
#      Cropped ROI  57 / 71  with  101  objects
#      Cropped ROI  58 / 71  with  101  objects
#      Cropped ROI  59 / 71  with  101  objects
#      Cropped ROI  60 / 71  with  101  objects
#      Cropped ROI  61 / 71  with  101  objects
#      Cropped ROI  62 / 71  with  101  objects
#      Cropped ROI  63 / 71  with  101  objects
#      Cropped ROI  64 / 71  with  101  objects
#      Cropped ROI  65 / 71  with  101  objects
#      Cropped ROI  66 / 71  with  101  objects
#      Cropped ROI  67 / 71  with  101  objects
#      Cropped ROI  68 / 71  with  101  objects
#      Cropped ROI  69 / 71  with  101  objects
#      Cropped ROI  70 / 71  with  101  objects
#      Cropped ROI  71 / 71  with  101  objects
# Cropping false positives...
#      Cropped ROI  1 / 66  with  100  objects
#      Cropped ROI  2 / 66  with  98  objects
#      Cropped ROI  3 / 66  with  100  objects
#      Cropped ROI  4 / 66  with  97  objects
#      Cropped ROI  5 / 66  with  92  objects
#      Cropped ROI  6 / 66  with  90  objects
#      Cropped ROI  7 / 66  with  103  objects
#      Cropped ROI  8 / 66  with  91  objects
#      Cropped ROI  9 / 66  with  104  objects
#      Cropped ROI  10 / 66  with  104  objects
#      Cropped ROI  11 / 66  with  98  objects
#      Cropped ROI  12 / 66  with  100  objects
#      Cropped ROI  13 / 66  with  98  objects
#      Cropped ROI  14 / 66  with  97  objects
#      Cropped ROI  15 / 66  with  98  objects
#      Cropped ROI  16 / 66  with  96  objects
#      Cropped ROI  17 / 66  with  98  objects
#      Cropped ROI  18 / 66  with  95  objects
#      Cropped ROI  19 / 66  with  103  objects
#      Cropped ROI  20 / 66  with  106  objects
#      Cropped ROI  21 / 66  with  93  objects
#      Cropped ROI  22 / 66  with  103  objects
#      Cropped ROI  23 / 66  with  101  objects
#      Cropped ROI  24 / 66  with  99  objects
#      Cropped ROI  25 / 66  with  103  objects
#      Cropped ROI  26 / 66  with  99  objects
#      Cropped ROI  27 / 66  with  96  objects
#      Cropped ROI  28 / 66  with  79  objects
#      Cropped ROI  29 / 66  with  99  objects
#      Cropped ROI  30 / 66  with  102  objects
#      Cropped ROI  31 / 66  with  90  objects
#      Cropped ROI  32 / 66  with  91  objects
#      Cropped ROI  33 / 66  with  90  objects
#      Cropped ROI  34 / 66  with  101  objects
#      Cropped ROI  35 / 66  with  104  objects
#      Cropped ROI  36 / 66  with  94  objects
#      Cropped ROI  37 / 66  with  98  objects
#      Cropped ROI  38 / 66  with  100  objects
#      Cropped ROI  39 / 66  with  88  objects
#      Cropped ROI  40 / 66  with  101  objects
#      Cropped ROI  41 / 66  with  99  objects
#      Cropped ROI  42 / 66  with  94  objects
#      Cropped ROI  43 / 66  with  97  objects
#      Cropped ROI  44 / 66  with  97  objects
#      Cropped ROI  45 / 66  with  104  objects
#      Cropped ROI  46 / 66  with  94  objects
#      Cropped ROI  47 / 66  with  98  objects
#      Cropped ROI  48 / 66  with  98  objects
#      Cropped ROI  49 / 66  with  99  objects
#      Cropped ROI  50 / 66  with  100  objects
#      Cropped ROI  51 / 66  with  96  objects
#      Cropped ROI  52 / 66  with  95  objects
#      Cropped ROI  53 / 66  with  102  objects
#      Cropped ROI  54 / 66  with  91  objects
#      Cropped ROI  55 / 66  with  93  objects
#      Cropped ROI  56 / 66  with  105  objects
#      Cropped ROI  57 / 66  with  95  objects
#      Cropped ROI  58 / 66  with  97  objects
#      Cropped ROI  59 / 66  with  93  objects
#      Cropped ROI  60 / 66  with  89  objects
#      Cropped ROI  61 / 66  with  102  objects
#      Cropped ROI  62 / 66  with  95  objects
#      Cropped ROI  63 / 66  with  95  objects
#      Cropped ROI  64 / 66  with  92  objects
#      Cropped ROI  65 / 66  with  98  objects
#      Cropped ROI  66 / 66  with  94  objects

# %%
if class_num == 2:
    print('train: ')    
    print('     object: ', len(os.listdir(obj_train_dir + 'object/')))
    print('     background: ', len(os.listdir(obj_train_dir + 'background/')))
    print('test: ')
    print('     object: ', len(os.listdir(obj_val_dir + 'object/')))
    print('     background: ', len(os.listdir(obj_val_dir + 'background/')))
elif class_num == 3:
    print('train: ')    
    print('     0: ', len(os.listdir(obj_train_dir + '0/')))
    print('     1: ', len(os.listdir(obj_train_dir + '1/')))
    print('     background: ', len(os.listdir(obj_train_dir + 'background/')))
    print('test: ')
    print('     0: ', len(os.listdir(obj_val_dir + '0/')))
    print('     1: ', len(os.listdir(obj_val_dir + '1/')))
    print('     background: ', len(os.listdir(obj_val_dir + 'background/')))
# Out:
# train:
#      0:  2871
#      1:  11436
#      background:  67429
# test:
#      0:  653
#      1:  2259
#      background:  13653
